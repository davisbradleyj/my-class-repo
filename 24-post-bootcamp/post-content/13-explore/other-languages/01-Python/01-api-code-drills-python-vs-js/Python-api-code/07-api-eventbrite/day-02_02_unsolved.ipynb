# %%
# Dependencies requests, pandas as "pd", pprint as pprint,
    # and your config file for api_key
    # Note: For the api_key check the "App Management" tab
        # You'll want to use the "Anonymous access OAuth token" or "Your personal OAuth token"

# %%
# Update panda's max column with by reviewing the following documentation.
    # This will be important later when dealing with larger columns.

# %%
# Set the url and query information for eventbrite
    # Check out www.eventbriteapi.com to review how to create queries.
    # Query for the following information:
        # url is ""
            # Please review documentation to get the base url for searching events.
                # https://www.eventbrite.com/developer/v3/quickstart/
                # https://www.eventbrite.com/developer/v3/endpoints/events/#ebapi-get-events-search
            # If still stuck, check 'hint.txt' for base url
        # price is "free"
        # event's name is "meetup"
        # location is "san francisco"
        



# Build query URL with the parameters mentioned above and api_key.
    # Don't forget to check documentation from link mentioned above for event searching.

# %%
# Create a variable "response" 
    # Set it to the response of the api call converted from json format.


# Use pprint to see the beautiful response.
# Out:
# {'events': [{'capacity': None,
#              'capacity_is_custom': None,
#              'category_id': None,
#              'changed': '2018-08-14T20:16:46Z',
#              'created': '2018-08-14T19:36:54Z',
#              'currency': 'USD',
#              'description': {'html': '<P>0x would like to invite you to a '
#                                      "small tech talk &amp; meet-up that we're "
#                                      'hosting at our office on Wednesday '
#                                      'August 29th from 5:30-7:30PM.</P>\n'
#                                      '<P>Will Warren and Amir Bandeali will be '
#                                      'presenting some of our newest updates '
#                                      'surrounding 0x V2 and answering any '
#                                      'questions.</P>',
#                              'text': '0x would like to invite you to a small '
#                                      "tech talk & meet-up that we're hosting "
#                                      'at our office on Wednesday August 29th '
#                                      'from 5:30-7:30PM.\n'
#                                      'Will Warren and Amir Bandeali will be '
#                                      'presenting some of our newest updates '
#                                      'surrounding 0x V2 and answering any '
#                                      'questions.'},
#              'end': {'local': '2018-08-29T19:30:00',
#                      'timezone': 'America/Los_Angeles',
#                      'utc': '2018-08-30T02:30:00Z'},
#              'format_id': None,
#              'hide_end_date': False,
#              'hide_start_date': False,
#              'id': '49107100660',
#              'is_free': True,
#              'is_locked': False,
#              'is_reserved_seating': False,
#              'is_series': False,
#              'is_series_parent': False,
#              'listed': True,
#              'locale': 'en_US',
#              'logo': {'aspect_ratio': '2',
#                       'crop_mask': {'height': 159,
#                                     'top_left': {'x': 0, 'y': 0},
#                                     'width': 318},
#                       'edge_color': '#404040',
#                       'edge_color_set': True,
#                       'id': '48417357',
#                       'original': {'height': 159,
#                                    'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F48417357%2F266794388670%2F1%2Foriginal.jpg?auto=compress&s=63b145e27c90983bfa2a12cc1caf1997',
#                                    'width': 318},
#                       'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F48417357%2F266794388670%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C0%2C318%2C159&s=55559b0f86deaf4f08e36025d7ff9511'},
#              'logo_id': '48417357',
#              'name': {'html': 'V2 Meetup', 'text': 'V2 Meetup'},
#              'online_event': False,
#              'organization_id': '266794388670',
#              'organizer_id': '17693295121',
#              'privacy_setting': 'unlocked',
#              'resource_uri': 'https://www.eventbriteapi.com/v3/events/49107100660/',
#              'shareable': True,
#              'show_colors_in_seatmap_thumbnail': False,
#              'show_pick_a_seat': False,
#              'show_seatmap_thumbnail': False,
#              'source': 'create_2.0',
#              'start': {'local': '2018-08-29T17:30:00',
#                        'timezone': 'America/Los_Angeles',
#                        'utc': '2018-08-30T00:30:00Z'},
#              'status': 'live',
#              'subcategory_id': None,
#              'tx_time_limit': 480,
#              'url': 'https://www.eventbrite.com/e/v2-meetup-tickets-49107100660?aff=ebapi',
#              'venue_id': '26212251',
#              'version': '3.0.0'},
#             {'capacity': None,
#              'capacity_is_custom': None,
#              'category_id': '199',
#              'changed': '2018-08-22T16:58:47Z',
#              'created': '2018-08-22T16:51:00Z',
#              'currency': 'USD',
#              'description': {'html': '<DIV CLASS="row flex-event">\n'
#                                      '<DIV CLASS="desc_cont">\n'
#                                      '<P>Join us on Friday, October 5 for the '
#                                      'fall Women in Leadership and Design '
#                                      '(W.I.L.D) meetup! Enjoy some post-work '
#                                      'drinks (psst the bar is CASH ONLY) and '
#                                      'network with like-minded women in the '
#                                      'San Francisco/Bay Area design '
#                                      'community.</P>\n'
#                                      "<P>21+ [Don't worry, our next meetup "
#                                      'will be all ages]</P>\n'
#                                      '<P><BR></P>\n'
#                                      '<HR>\n'
#                                      '<P><BR></P>\n'
#                                      '<P><SPAN>AIGA SF’s Women in Leadership '
#                                      'and Design (WILD) initiative aims for '
#                                      'gender parity in design. The purpose of '
#                                      'WILD Programming, meetups and workshops '
#                                      'is to empower women and genderqueer '
#                                      'persons at every stage on their path to '
#                                      'leadership.</SPAN></P>\n'
#                                      '<P><BR></P>\n'
#                                      '<DIV CLASS="row '
#                                      'row-speakers"><BR></DIV>\n'
#                                      '</DIV>\n'
#                                      '</DIV>\n'
#                                      '<DIV CLASS="button-holder '
#                                      'enclose-signup-event"><BR></DIV>',
#                              'text': '\n'
#                                      '\n'
#                                      'Join us on Friday, October 5 for the '
#                                      'fall Women in Leadership and Design '
#                                      '(W.I.L.D) meetup! Enjoy some post-work '
#                                      'drinks (psst the bar is CASH ONLY) and '
#                                      'network with like-minded women in the '
#                                      'San Francisco/Bay Area design '
#                                      'community.\n'
#                                      "21+ [Don't worry, our next meetup will "
#                                      'be all ages]\n'
#                                      '\n'
#                                      '\n'
#                                      '\n'
#                                      'AIGA SF’s Women in Leadership and Design '
#                                      '(WILD) initiative aims for gender parity '
#                                      'in design. The purpose of WILD '
#                                      'Programming, meetups and workshops is to '
#                                      'empower women and genderqueer persons at '
#                                      'every stage on their path to '
#                                      'leadership.\n'
#                                      '\n'
#                                      '\n'
#                                      '\n'
#                                      '\n'},
#              'end': {'local': '2018-10-05T19:30:00',
#                      'timezone': 'America/Los_Angeles',
#                      'utc': '2018-10-06T02:30:00Z'},
#              'format_id': '10',
#              'hide_end_date': False,
#              'hide_start_date': False,
#              'id': '49391290680',
#              'is_free': True,
#              'is_locked': False,
#              'is_reserved_seating': False,
#              'is_series': False,
#              'is_series_parent': False,
#              'listed': True,
#              'locale': 'en_US',
#              'logo': {'aspect_ratio': '2',
#                       'crop_mask': {'height': 2500,
#                                     'top_left': {'x': 0, 'y': 0},
#                                     'width': 5000},
#                       'edge_color': '#ffffff',
#                       'edge_color_set': True,
#                       'id': '48754004',
#                       'original': {'height': 2500,
#                                    'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F48754004%2F32515023%2F1%2Foriginal.jpg?auto=compress&s=b0551d2264cbebf2f83a6b04039e317c',
#                                    'width': 5000},
#                       'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F48754004%2F32515023%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C0%2C5000%2C2500&s=fcf5024e2bd92e9f6cb9a848d8fc538c'},
#              'logo_id': '48754004',
#              'name': {'html': 'Women in Leadership and Design Fall Meetup',
#                       'text': 'Women in Leadership and Design Fall Meetup'},
#              'online_event': False,
#              'organization_id': '32515023',
#              'organizer_id': '33964096',
#              'privacy_setting': 'unlocked',
#              'resource_uri': 'https://www.eventbriteapi.com/v3/events/49391290680/',
#              'shareable': True,
#              'show_colors_in_seatmap_thumbnail': False,
#              'show_pick_a_seat': False,
#              'show_seatmap_thumbnail': False,
#              'source': 'create_2.0',
#              'start': {'local': '2018-10-05T17:30:00',
#                        'timezone': 'America/Los_Angeles',
#                        'utc': '2018-10-06T00:30:00Z'},
#              'status': 'live',
#              'subcategory_id': None,
#              'tx_time_limit': 1800,
#              'url': 'https://www.eventbrite.com/e/women-in-leadership-and-design-fall-meetup-tickets-49391290680?aff=ebapi',
#              'venue_id': '26351663',
#              'version': '3.0.0'},
#             {'capacity': None,
#              'capacity_is_custom': None,
#              'category_id': '101',
#              'changed': '2018-07-31T04:34:40Z',
#              'created': '2018-07-31T03:14:50Z',
#              'currency': 'USD',
#              'description': {'html': '<P>Join other engineering leaders and '
#                                      'managers in discussing the most '
#                                      'impactful books in our profession. '
#                                      'Through our small-format book readings '
#                                      '(limited to 8 people), each of us will '
#                                      'have an opportunity to introduce '
#                                      'ourselves and have a tangible impact in '
#                                      'the conversation.</P>\n'
#                                      '<P><STRONG><A '
#                                      'HREF="https://www.amazon.com/High-Growth-Handbook-Elad-Gil/dp/1732265100/" '
#                                      'TARGET="_blank" REL="noreferrer noopener '
#                                      'nofollow noopener noreferrer '
#                                      'nofollow">Buy the High Growth Handbook '
#                                      'at Amazon.com</A>.\xa0</STRONG><EM>(Now '
#                                      'shipping!)</EM></P>\n'
#                                      '<P><STRONG>Schedule</STRONG>:</P>\n'
#                                      '<UL>\n'
#                                      '<LI>7:00pm - Introductions</LI>\n'
#                                      '<LI>7:15pm - Background on the Book '
#                                      '&amp; Author</LI>\n'
#                                      '<LI>7:20pm - Round-robin reflections on '
#                                      'each chapter.</LI>\n'
#                                      '<LI>8:00pm - Open forum</LI>\n'
#                                      '<LI>8:30pm - Adjournment</LI>\n'
#                                      '</UL>\n'
#                                      '<P>Get the most of the meeting by '
#                                      'bringing the most...<STRONG>read the '
#                                      'book in its entirety</STRONG>!</P>\n'
#                                      '<P><STRONG>About the Book:</STRONG> \xa0'
#                                      'High Growth Handbook is the playbook for '
#                                      'turning a startup into a unicorn and '
#                                      'navigating the most complex challenges '
#                                      'that confront leaders and operators in '
#                                      'high-growth startups. It covers key '
#                                      'topics like the role of the CEO, '
#                                      'managing the board, recruiting and '
#                                      'managing an executive team, M&A, IPOs '
#                                      'and late-stage funding rounds, and is '
#                                      'interspersed with over a dozen '
#                                      'interviews with some of the most '
#                                      'influential leaders in Silicon Valley '
#                                      'including Reid Hoffman (LinkedIn), Marc '
#                                      'Andreessen (Andreessen Horowitz), and '
#                                      'Aaron Levie (Box).</P>\n'
#                                      '<P><STRONG>About the Author: \xa0'
#                                      '</STRONG>Elad Gil is an entrepreneur, '
#                                      'operating executive, and investor or '
#                                      'advisor to private companies such as '
#                                      'Airbnb, Coinbase, Checkr, Gusto, '
#                                      'Instacart, OpenDoor, Pinterest, Square, '
#                                      'Stripe, Wish, and others. He is '
#                                      'cofounder and chairman at Color '
#                                      'Genomics. \xa0 Previously, he was the VP '
#                                      'of Corporate Strategy at Twitter, where '
#                                      'he also ran various product (Geo, '
#                                      'Search) and other operational teams (M&A '
#                                      'and Corporate Development). Elad joined '
#                                      'Twitter via the acquisition of '
#                                      'MixerLabs, a company where he was '
#                                      'co-founder and CEO. MixerLabs ran '
#                                      'GeoAPI, one of the early '
#                                      'developer-centric platform '
#                                      'infrastructure products. Elad spent many '
#                                      'years at Google, where he started the '
#                                      'mobile team and was involved in all '
#                                      'aspects of getting that team up and '
#                                      'running. He was involved with three '
#                                      'acquisitions (including the Android '
#                                      'team) and was the original product '
#                                      'manager for Google Mobile Maps and other '
#                                      'key mobile products. \xa0 Prior to '
#                                      'Google, Elad had product management and '
#                                      'market-seeding roles at a number of '
#                                      'Silicon Valley companies. He also worked '
#                                      'at McKinsey &amp; Co. Elad received his '
#                                      'Ph.D. from the Massachusetts Institute '
#                                      'of Technology and has degrees in '
#                                      'Mathematics and Biology from the '
#                                      'University of California, San Diego.</P>',
#                              'text': 'Join other engineering leaders and '
#                                      'managers in discussing the most '
#                                      'impactful books in our profession. '
#                                      'Through our small-format book readings '
#                                      '(limited to 8 people), each of us will '
#                                      'have an opportunity to introduce '
#                                      'ourselves and have a tangible impact in '
#                                      'the conversation.\n'
#                                      'Buy the High Growth Handbook at '
#                                      'Amazon.com.\xa0(Now shipping!)\n'
#                                      'Schedule:\n'
#                                      '\n'
#                                      '7:00pm - Introductions\n'
#                                      '7:15pm - Background on the Book & '
#                                      'Author\n'
#                                      '7:20pm - Round-robin reflections on each '
#                                      'chapter.\n'
#                                      '8:00pm - Open forum\n'
#                                      '8:30pm - Adjournment\n'
#                                      '\n'
#                                      'Get the most of the meeting by bringing '
#                                      'the most...read the book in its '
#                                      'entirety!\n'
#                                      'About the Book: \xa0High Growth Handbook '
#                                      'is the playbook for turning a startup '
#                                      'into a unicorn and navigating the most '
#                                      'complex challenges that confront leaders '
#                                      'and operators in high-growth startups. '
#                                      'It covers key topics like the role of '
#                                      'the CEO, managing the board, recruiting '
#                                      'and managing an executive team, M&A, '
#                                      'IPOs and late-stage funding rounds, and '
#                                      'is interspersed with over a dozen '
#                                      'interviews with some of the most '
#                                      'influential leaders in Silicon Valley '
#                                      'including Reid Hoffman (LinkedIn), Marc '
#                                      'Andreessen (Andreessen Horowitz), and '
#                                      'Aaron Levie (Box).\n'
#                                      'About the Author: \xa0Elad Gil is an '
#                                      'entrepreneur, operating executive, and '
#                                      'investor or advisor to private companies '
#                                      'such as Airbnb, Coinbase, Checkr, Gusto, '
#                                      'Instacart, OpenDoor, Pinterest, Square, '
#                                      'Stripe, Wish, and others. He is '
#                                      'cofounder and chairman at Color '
#                                      'Genomics. \xa0 Previously, he was the VP '
#                                      'of Corporate Strategy at Twitter, where '
#                                      'he also ran various product (Geo, '
#                                      'Search) and other operational teams (M&A '
#                                      'and Corporate Development). Elad joined '
#                                      'Twitter via the acquisition of '
#                                      'MixerLabs, a company where he was '
#                                      'co-founder and CEO. MixerLabs ran '
#                                      'GeoAPI, one of the early '
#                                      'developer-centric platform '
#                                      'infrastructure products. Elad spent many '
#                                      'years at Google, where he started the '
#                                      'mobile team and was involved in all '
#                                      'aspects of getting that team up and '
#                                      'running. He was involved with three '
#                                      'acquisitions (including the Android '
#                                      'team) and was the original product '
#                                      'manager for Google Mobile Maps and other '
#                                      'key mobile products. \xa0 Prior to '
#                                      'Google, Elad had product management and '
#                                      'market-seeding roles at a number of '
#                                      'Silicon Valley companies. He also worked '
#                                      'at McKinsey & Co. Elad received his '
#                                      'Ph.D. from the Massachusetts Institute '
#                                      'of Technology and has degrees in '
#                                      'Mathematics and Biology from the '
#                                      'University of California, San Diego.'},
#              'end': {'local': '2018-08-23T20:30:00',
#                      'timezone': 'America/Los_Angeles',
#                      'utc': '2018-08-24T03:30:00Z'},
#              'format_id': '10',
#              'hide_end_date': False,
#              'hide_start_date': False,
#              'id': '48582823533',
#              'is_free': True,
#              'is_locked': False,
#              'is_reserved_seating': False,
#              'is_series': True,
#              'is_series_parent': False,
#              'listed': True,
#              'locale': 'en_US',
#              'logo': {'aspect_ratio': '2',
#                       'crop_mask': {'height': 960,
#                                     'top_left': {'x': 0, 'y': 29},
#                                     'width': 1920},
#                       'edge_color': '#321300',
#                       'edge_color_set': True,
#                       'id': '47804292',
#                       'original': {'height': 1080,
#                                    'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F47804292%2F772682177%2F1%2Foriginal.jpg?auto=compress&s=7a181b4343a57d4478011dc12547df75',
#                                    'width': 1920},
#                       'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F47804292%2F772682177%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C29%2C1920%2C960&s=a2d8f088a3617fbd2d3cf890f05c7730'},
#              'logo_id': '47804292',
#              'name': {'html': 'High Growth Handbook - Reader Meetup',
#                       'text': 'High Growth Handbook - Reader Meetup'},
#              'online_event': False,
#              'organization_id': '772682177',
#              'organizer_id': '17602910829',
#              'privacy_setting': 'unlocked',
#              'resource_uri': 'https://www.eventbriteapi.com/v3/events/48582823533/',
#              'series_id': '48582445402',
#              'shareable': True,
#              'show_colors_in_seatmap_thumbnail': False,
#              'show_pick_a_seat': False,
#              'show_seatmap_thumbnail': False,
#              'source': 'create_2.0',
#              'start': {'local': '2018-08-23T19:00:00',
#                        'timezone': 'America/Los_Angeles',
#                        'utc': '2018-08-24T02:00:00Z'},
#              'status': 'live',
#              'subcategory_id': '1010',
#              'tx_time_limit': 480,
#              'url': 'https://www.eventbrite.com/e/high-growth-handbook-reader-meetup-tickets-48582823533?aff=ebapi',
#              'venue_id': '25832053',
#              'version': '3.0.0'},
#             {'capacity': None,
#              'capacity_is_custom': None,
#              'category_id': '107',
#              'changed': '2018-07-12T08:02:24Z',
#              'created': '2018-07-12T07:57:35Z',
#              'currency': 'USD',
#              'description': {'html': '<P><SPAN>We are a simply a group of '
#                                      'people who are interested in meditation '
#                                      'and enjoy the experience of meditating '
#                                      'together in a group. The meditation '
#                                      'style is up to you, there are no rules '
#                                      'about this. The meetings are suitable '
#                                      'for both beginners and seasoned '
#                                      'meditators.</SPAN><BR><BR><SPAN>After '
#                                      'the meditation, we read a thoughtful '
#                                      'passage followed by discussion. You can '
#                                      'find more information about the meetings '
#                                      'in the About (</SPAN><A CLASS="link" '
#                                      'HREF="http://www.meetup.com/sf-meditation/pages/What_to_expect_at_the_meditation_meetup/" '
#                                      'TARGET="__blank" '
#                                      'TITLE="http://www.meetup.com/sf-meditation/pages/What_to_expect_at_the_meditation_meetup/" '
#                                      'REL="nofollow">http://www.meetup.com/sf-meditation/pages/What_to_expect_at_the_meditation_meetup/</A><SPAN>) '
#                                      'section.</SPAN></P>',
#                              'text': 'We are a simply a group of people who '
#                                      'are interested in meditation and enjoy '
#                                      'the experience of meditating together in '
#                                      'a group. The meditation style is up to '
#                                      'you, there are no rules about this. The '
#                                      'meetings are suitable for both beginners '
#                                      'and seasoned meditators.After the '
#                                      'meditation, we read a thoughtful passage '
#                                      'followed by discussion. You can find '
#                                      'more information about the meetings in '
#                                      'the About '
#                                      '(http://www.meetup.com/sf-meditation/pages/What_to_expect_at_the_meditation_meetup/) '
#                                      'section.'},
#              'end': {'local': '2018-08-24T20:00:00',
#                      'timezone': 'America/Los_Angeles',
#                      'utc': '2018-08-25T03:00:00Z'},
#              'format_id': '11',
#              'hide_end_date': False,
#              'hide_start_date': False,
#              'id': '48021422367',
#              'is_free': True,
#              'is_locked': False,
#              'is_reserved_seating': False,
#              'is_series': True,
#              'is_series_parent': False,
#              'listed': True,
#              'locale': 'en_US',
#              'logo': {'aspect_ratio': '2',
#                       'crop_mask': {'height': 2016,
#                                     'top_left': {'x': 0, 'y': 534},
#                                     'width': 4032},
#                       'edge_color': '#a1988b',
#                       'edge_color_set': True,
#                       'id': '47130390',
#                       'original': {'height': 3024,
#                                    'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F47130390%2F154430699393%2F1%2Foriginal.jpg?auto=compress&s=6e14c131cc7cbaa9b310385037e074db',
#                                    'width': 4032},
#                       'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F47130390%2F154430699393%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C534%2C4032%2C2016&s=4edb88df768ca353e847d962011898f4'},
#              'logo_id': '47130390',
#              'name': {'html': 'Group Meditation and Meetup - (Free Format)',
#                       'text': 'Group Meditation and Meetup - (Free Format)'},
#              'online_event': False,
#              'organization_id': '154430699393',
#              'organizer_id': '16289138349',
#              'privacy_setting': 'unlocked',
#              'resource_uri': 'https://www.eventbriteapi.com/v3/events/48021422367/',
#              'series_id': '48021416349',
#              'shareable': True,
#              'show_colors_in_seatmap_thumbnail': False,
#              'show_pick_a_seat': False,
#              'show_seatmap_thumbnail': False,
#              'source': 'create_2.0',
#              'start': {'local': '2018-08-24T18:30:00',
#                        'timezone': 'America/Los_Angeles',
#                        'utc': '2018-08-25T01:30:00Z'},
#              'status': 'live',
#              'subcategory_id': '7005',
#              'tx_time_limit': 480,
#              'url': 'https://www.eventbrite.com/e/group-meditation-and-meetup-free-format-tickets-48021422367?aff=ebapi',
#              'venue_id': '24596547',
#              'version': '3.0.0'},
#             {'capacity': None,
#              'capacity_is_custom': None,
#              'category_id': '105',
#              'changed': '2018-08-18T19:55:54Z',
#              'created': '2018-08-16T19:33:55Z',
#              'currency': 'USD',
#              'description': {'html': '<P><SPAN>A taste of improv where we play '
#                                      'improv games!</SPAN><BR><SPAN>This '
#                                      'Meetup is for beginners and improvisers '
#                                      'of all skill '
#                                      'levels.</SPAN><BR><BR><STRONG>Why '
#                                      'Improv?</STRONG><BR><SPAN>Improv helps '
#                                      'people:</SPAN><BR><SPAN>- Listen and be '
#                                      'present</SPAN><BR><SPAN>- Tap into '
#                                      'creativity</SPAN><BR><SPAN>- Be better '
#                                      'communicators</SPAN><BR><SPAN>- '
#                                      'Celebrate making mistakes and be more '
#                                      'resilient</SPAN><BR><SPAN>- Gracefully '
#                                      'deal with uncertainty</SPAN><BR><SPAN>- '
#                                      'Make your partners look good and '
#                                      'collaborate more '
#                                      'effectively</SPAN><BR><BR><SPAN>YES AND '
#                                      'in addition to being useful, improv is '
#                                      'fun! Join us for an intro to improv '
#                                      'through improv '
#                                      'games!</SPAN><BR><BR><STRONG>You Will '
#                                      'Learn</STRONG><BR><SPAN>- Foundation '
#                                      'principles of improv (e.g. YES AND, '
#                                      'happy healthy well, being present, eye '
#                                      'contact and listening, making your '
#                                      'partner look good, accepting mistakes '
#                                      'and how they can be gifts, being '
#                                      'obvious, etc.)</SPAN><BR><SPAN>- Fun '
#                                      'improv games that improve listening '
#                                      'skills, teamwork and '
#                                      'communication</SPAN><BR><SPAN>- Improv '
#                                      'games that you can teach to your team, '
#                                      'friends and '
#                                      'family!</SPAN><BR><BR><STRONG>Who Should '
#                                      'Attend '
#                                      '(audience)</STRONG><BR><SPAN>Anyone who '
#                                      'want to try improv, play games and have '
#                                      'fun!</SPAN><BR><BR><SPAN>What kinds of '
#                                      'people attend? All sorts, '
#                                      'including:</SPAN><BR><SPAN>- Developers '
#                                      '/ Engineers</SPAN><BR><SPAN>- Actors who '
#                                      'want to be more in the moment and '
#                                      'flexible on set</SPAN><BR><SPAN>- '
#                                      'Directors looking for a creative '
#                                      'outlet</SPAN><BR><SPAN>- Founders and '
#                                      'executives</SPAN><BR><SPAN>- '
#                                      'Designers</SPAN><BR><SPAN>- Product '
#                                      'Managers</SPAN><BR><SPAN>- '
#                                      'etc.</SPAN><BR><BR><EM><STRONG>*Note:</STRONG></EM><BR><SPAN>- '
#                                      'Limited to 30 in person attendees. First '
#                                      'come, first served at the '
#                                      'location.</SPAN><BR><SPAN>- Donations '
#                                      '($20 to $45) are encouraged but not '
#                                      'required. We accept cash or Venmo '
#                                      '@jaredpolivka</SPAN><BR></P>\n'
#                                      '<P><STRONG>**</STRONG><BR>Remember to '
#                                      'join the SF Improv Meetup:\xa0'
#                                      '<BR>https://www.meetup.com/SF-Improv</P>\n'
#                                      '<P><BR></P>\n'
#                                      '<P><EM><STRONG>***</STRONG><BR>Check out '
#                                      'these posts about '
#                                      'improv:</EM><BR><SPAN>-\xa0</SPAN><A '
#                                      'CLASS="link" '
#                                      'HREF="https://www.forbes.com/sites/forbesleadershipforum/2014/06/27/why-improv-training-is-great-business-training/#3079236a6bcb" '
#                                      'TARGET="__blank" '
#                                      'TITLE="https://www.forbes.com/sites/forbesleadershipforum/2014/06/27/why-improv-training-is-great-business-training/#3079236a6bcb" '
#                                      'REL="nofollow">https://www.forbes.com/sites/forbesleadershipforum/2014/06/27/why-improv-training-is-great-business-training/#3079236a6bcb</A><BR><BR><SPAN>-\xa0'
#                                      '</SPAN><A CLASS="link" '
#                                      'HREF="https://medium.com/personal-growth/what-improv-can-teach-you-about-startup-life-a699c55a1548" '
#                                      'TARGET="__blank" '
#                                      'TITLE="https://medium.com/personal-growth/what-improv-can-teach-you-about-startup-life-a699c55a1548" '
#                                      'REL="nofollow">https://medium.com/personal-growth/what-improv-can-teach-you-about-startup-life-a699c55a1548</A><BR><BR><SPAN>-\xa0'
#                                      '</SPAN><A CLASS="link" '
#                                      'HREF="https://blog.hootsuite.com/brainstorm-lessons-from-improv" '
#                                      'TARGET="__blank" '
#                                      'TITLE="https://blog.hootsuite.com/brainstorm-lessons-from-improv" '
#                                      'REL="nofollow">https://blog.hootsuite.com/brainstorm-lessons-from-improv</A><BR><BR><SPAN>-\xa0'
#                                      '</SPAN><A CLASS="link" '
#                                      'HREF="https://medium.com/startup-grind/two-words-that-make-you-a-better-founder-8b226b0bbc0a" '
#                                      'TARGET="__blank" '
#                                      'TITLE="https://medium.com/startup-grind/two-words-that-make-you-a-better-founder-8b226b0bbc0a" '
#                                      'REL="nofollow">https://medium.com/startup-grind/two-words-that-make-you-a-better-founder-8b226b0bbc0a</A></P>',
#                              'text': 'A taste of improv where we play improv '
#                                      'games!This Meetup is for beginners and '
#                                      'improvisers of all skill levels.Why '
#                                      'Improv?Improv helps people:- Listen and '
#                                      'be present- Tap into creativity- Be '
#                                      'better communicators- Celebrate making '
#                                      'mistakes and be more resilient- '
#                                      'Gracefully deal with uncertainty- Make '
#                                      'your partners look good and collaborate '
#                                      'more effectivelyYES AND in addition to '
#                                      'being useful, improv is fun! Join us for '
#                                      'an intro to improv through improv '
#                                      'games!You Will Learn- Foundation '
#                                      'principles of improv (e.g. YES AND, '
#                                      'happy healthy well, being present, eye '
#                                      'contact and listening, making your '
#                                      'partner look good, accepting mistakes '
#                                      'and how they can be gifts, being '
#                                      'obvious, etc.)- Fun improv games that '
#                                      'improve listening skills, teamwork and '
#                                      'communication- Improv games that you can '
#                                      'teach to your team, friends and '
#                                      'family!Who Should Attend '
#                                      '(audience)Anyone who want to try improv, '
#                                      'play games and have fun!What kinds of '
#                                      'people attend? All sorts, including:- '
#                                      'Developers / Engineers- Actors who want '
#                                      'to be more in the moment and flexible on '
#                                      'set- Directors looking for a creative '
#                                      'outlet- Founders and executives- '
#                                      'Designers- Product Managers- etc.*Note:- '
#                                      'Limited to 30 in person attendees. First '
#                                      'come, first served at the location.- '
#                                      'Donations ($20 to $45) are encouraged '
#                                      'but not required. We accept cash or '
#                                      'Venmo @jaredpolivka\n'
#                                      '**Remember to join the SF Improv '
#                                      'Meetup:\xa0'
#                                      'https://www.meetup.com/SF-Improv\n'
#                                      '\n'
#                                      '***Check out these posts about '
#                                      'improv:-\xa0'
#                                      'https://www.forbes.com/sites/forbesleadershipforum/2014/06/27/why-improv-training-is-great-business-training/#3079236a6bcb-\xa0'
#                                      'https://medium.com/personal-growth/what-improv-can-teach-you-about-startup-life-a699c55a1548-\xa0'
#                                      'https://blog.hootsuite.com/brainstorm-lessons-from-improv-\xa0'
#                                      'https://medium.com/startup-grind/two-words-that-make-you-a-better-founder-8b226b0bbc0a'},
#              'end': {'local': '2018-09-08T18:30:00',
#                      'timezone': 'America/Los_Angeles',
#                      'utc': '2018-09-09T01:30:00Z'},
#              'format_id': '9',
#              'hide_end_date': False,
#              'hide_start_date': False,
#              'id': '49189474041',
#              'is_free': True,
#              'is_locked': False,
#              'is_reserved_seating': False,
#              'is_series': False,
#              'is_series_parent': False,
#              'listed': True,
#              'locale': 'en_US',
#              'logo': {'aspect_ratio': '2',
#                       'crop_mask': {'height': 500,
#                                     'top_left': {'x': 0, 'y': 78},
#                                     'width': 1000},
#                       'edge_color': '#463f3c',
#                       'edge_color_set': True,
#                       'id': '48518605',
#                       'original': {'height': 667,
#                                    'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F48518605%2F3272500264%2F1%2Foriginal.jpg?auto=compress&s=bb1d40eed625fc2ab3e12d5d218803b7',
#                                    'width': 1000},
#                       'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F48518605%2F3272500264%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C78%2C1000%2C500&s=d80bc38ffd62fc8c9df6c969beec83f1'},
#              'logo_id': '48518605',
#              'name': {'html': 'SF Improv Meetup - Improv Games!',
#                       'text': 'SF Improv Meetup - Improv Games!'},
#              'online_event': False,
#              'organization_id': '181532751992',
#              'organizer_id': '15235782111',
#              'privacy_setting': 'unlocked',
#              'resource_uri': 'https://www.eventbriteapi.com/v3/events/49189474041/',
#              'shareable': True,
#              'show_colors_in_seatmap_thumbnail': False,
#              'show_pick_a_seat': False,
#              'show_seatmap_thumbnail': False,
#              'source': 'create_2.0',
#              'start': {'local': '2018-09-08T15:30:00',
#                        'timezone': 'America/Los_Angeles',
#                        'utc': '2018-09-08T22:30:00Z'},
#              'status': 'live',
#              'subcategory_id': None,
#              'tx_time_limit': 600,
#              'url': 'https://www.eventbrite.com/e/sf-improv-meetup-improv-games-tickets-49189474041?aff=ebapi',
#              'venue_id': '23360334',
#              'version': '3.0.0'},
#             {'capacity': None,
#              'capacity_is_custom': None,
#              'category_id': '101',
#              'changed': '2018-08-17T17:44:54Z',
#              'created': '2018-08-17T17:35:51Z',
#              'currency': 'USD',
#              'description': {'html': '<P>Come meet your peers in SF at our '
#                                      'People Ops Collective monthly meetup. '
#                                      'This is an opportunity for us to come '
#                                      'together after work and learn from one '
#                                      'another over drinks. This isn’t a '
#                                      'speaker event, but rather, an intimate '
#                                      'setting for us to chat as equals. Let’s '
#                                      'share resources, help one another with '
#                                      'our projects, and simply connect to get '
#                                      'to know our peers. Can’t wait to meet '
#                                      'you!</P>',
#                              'text': 'Come meet your peers in SF at our People '
#                                      'Ops Collective monthly meetup. This is '
#                                      'an opportunity for us to come together '
#                                      'after work and learn from one another '
#                                      'over drinks. This isn’t a speaker event, '
#                                      'but rather, an intimate setting for us '
#                                      'to chat as equals. Let’s share '
#                                      'resources, help one another with our '
#                                      'projects, and simply connect to get to '
#                                      'know our peers. Can’t wait to meet you!'},
#              'end': {'local': '2018-09-19T20:00:00',
#                      'timezone': 'America/Los_Angeles',
#                      'utc': '2018-09-20T03:00:00Z'},
#              'format_id': '10',
#              'hide_end_date': False,
#              'hide_start_date': False,
#              'id': '49223029406',
#              'is_free': True,
#              'is_locked': False,
#              'is_reserved_seating': False,
#              'is_series': False,
#              'is_series_parent': False,
#              'listed': True,
#              'locale': 'en_US',
#              'logo': {'aspect_ratio': '2',
#                       'crop_mask': {'height': 500,
#                                     'top_left': {'x': 157, 'y': 0},
#                                     'width': 1000},
#                       'edge_color': '#ffffff',
#                       'edge_color_set': True,
#                       'id': '48559331',
#                       'original': {'height': 500,
#                                    'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F48559331%2F174391974012%2F1%2Foriginal.jpg?auto=compress&s=a8a248813f759ba2b65cfa021a710521',
#                                    'width': 1315},
#                       'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F48559331%2F174391974012%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=157%2C0%2C1000%2C500&s=3ceb617d6d1e09c7dff39db02ecc3300'},
#              'logo_id': '48559331',
#              'name': {'html': 'People Ops Collective (monthly meetup)',
#                       'text': 'People Ops Collective (monthly meetup)'},
#              'online_event': False,
#              'organization_id': '174391974012',
#              'organizer_id': '13075977574',
#              'privacy_setting': 'unlocked',
#              'resource_uri': 'https://www.eventbriteapi.com/v3/events/49223029406/',
#              'shareable': True,
#              'show_colors_in_seatmap_thumbnail': False,
#              'show_pick_a_seat': False,
#              'show_seatmap_thumbnail': False,
#              'source': 'create_2.0',
#              'start': {'local': '2018-09-19T18:00:00',
#                        'timezone': 'America/Los_Angeles',
#                        'utc': '2018-09-20T01:00:00Z'},
#              'status': 'live',
#              'subcategory_id': '1010',
#              'tx_time_limit': 480,
#              'url': 'https://www.eventbrite.com/e/people-ops-collective-monthly-meetup-tickets-49223029406?aff=ebapi',
#              'venue_id': '25484199',
#              'version': '3.0.0'},
#             {'capacity': None,
#              'capacity_is_custom': None,
#              'category_id': '101',
#              'changed': '2018-08-17T22:25:20Z',
#              'created': '2018-06-08T00:11:01Z',
#              'currency': 'USD',
#              'description': {'html': '<P><STRONG>THINKIFIC USER MEETUP IN SAN '
#                                      'FRANCISCO!</STRONG></P>\n'
#                                      '<P>Join us for a casual evening of '
#                                      'learning and networking with Jean Pak '
#                                      '(our New York Thinkific Ambassador) who '
#                                      'will be visiting San Francisco and will '
#                                      'be hosting a Meetup to network with '
#                                      'other like-minded course creators from '
#                                      'the Bay Area.</P>\n'
#                                      '<P><SPAN><STRONG>NEW TO '
#                                      'THINKIFIC?</STRONG> Grab this Free '
#                                      'Starter Pack that includes Free Time on '
#                                      'our Business Plan, Onboarding Calls, and '
# ...
#                                      'to attend. This cost represents the time '
#                                      'required to organize the mission and '
#                                      'goes to help reimburse DIT for some of '
#                                      'the costs involved in hosting this '
#                                      'event. In addition to this cost, '
#                                      'delegates are responsible for their own '
#                                      'airfare, hotel, and some '
#                                      'meals.</SPAN></P>\n'
#                                      '<UL>\n'
#                                      '<LI>\n'
#                                      '<H4><STRONG>Applications must be '
#                                      'received no later than 23.30 PDT on 31 '
#                                      'August, 2018</STRONG></H4>\n'
#                                      '</LI>\n'
#                                      '<LI>\n'
#                                      '<H4><STRONG>Accepted delegates will be '
#                                      'notified by 5th September, 2018\xa0and '
#                                      'must confirm their space in the '
#                                      'delegation by 10 September, '
#                                      '2018</STRONG></H4>\n'
#                                      '</LI>\n'
#                                      '</UL>\n'
#                                      '<P CLASS="MsoNormal"><SPAN>Acceptance is '
#                                      'non-transferable and completion of the '
#                                      'application does not guarantee '
#                                      'acceptance. Selection is determined '
#                                      'through a competitive review process. '
#                                      'For any questions, please contact '
#                                      '<EM>max.lelu@mobile.trade.gov.uk</EM></SPAN></P>',
#                              'text': 'The UK’s Department for International '
#                                      'Trade is proud to present their annual '
#                                      'Mission to the SF FinTech Week from '
#                                      '12-16 November, 2018.\n'
#                                      '**Please note, the Aug 1-31 date on the '
#                                      'event indicates the dates that the '
#                                      'application window is open - not the '
#                                      'date of the mission **\n'
#                                      'This mission offers British FinTechs the '
#                                      'opportunity to showcase their expertise '
#                                      'to the US market, as well as engage with '
#                                      'US regulators, VCs, Industry players, '
#                                      'and gain insight into overcoming '
#                                      'barriers to doing business overseas.  '
#                                      'DIT SF is recruiting UK FinTechs to join '
#                                      'us for five days of workshops, '
#                                      'networking events, 1:1 meetings and much '
#                                      'more. Previous missions have seen UK '
#                                      'companies raise millions in funding from '
#                                      'Silicon Valley VCs, acquire large '
#                                      'customer accounts, learn best practices '
#                                      'about US expansion strategy and business '
#                                      'development, as well as network with '
#                                      'top-level industry executives, and '
#                                      'engage with US regulators.\xa0Ideal '
#                                      'candidates are those actively entering '
#                                      'the US market, or already have US '
#                                      'clients.   What to expect on the 2018 '
#                                      'FinTech Mission to SF and Silicon '
#                                      'Valley:\xa0\n'
#                                      '\n'
#                                      '\n'
#                                      'Pre-mission briefing in London in early '
#                                      'November\n'
#                                      '\n'
#                                      '\n'
#                                      'Exclusive VC pitch opportunities\n'
#                                      '\n'
#                                      '\n'
#                                      'Participation in San Francisco Fintech '
#                                      'Week events and conferences\n'
#                                      '\n'
#                                      '\n'
#                                      'Regulatory discussions with local '
#                                      'regulators and legal experts\n'
#                                      '\n'
#                                      '\n'
#                                      'Network with senior executives in '
#                                      'venture capital, fintech, banking, '
#                                      'insurance, asset management, technology '
#                                      "and finance during San Francisco's "
#                                      'FinTech Week\n'
#                                      '\n'
#                                      '\n'
#                                      'Group visits and 1:1 meetings with '
#                                      'financial services leaders, including '
#                                      'Paypal and Visa\n'
#                                      '\n'
#                                      '\n'
#                                      'Tour the innovation labs of some of the '
#                                      'largest players in the financial '
#                                      'industry\n'
#                                      '\n'
#                                      '\n'
#                                      'Participate in presentations, panels, '
#                                      'and workshops covering important issues '
#                                      'facing UK tech companies growing their '
#                                      'businesses in the US\n'
#                                      '\n'
#                                      '\n'
#                                      'Learn from industry insiders about '
#                                      'financing, hiring, and doing business in '
#                                      'Silicon Valley and the greater Bay Area\n'
#                                      '\n'
#                                      '\n'
#                                      'Company bio in digital and printed '
#                                      'mission brochure\n'
#                                      '\n'
#                                      '\n'
#                                      'Attend an invite-only reception with an '
#                                      'executives-only expats in tech '
#                                      'networking group\n'
#                                      '\n'
#                                      '\n'
#                                      'Pitch and showcase opportunities '
#                                      'throughout the week\n'
#                                      '\n'
#                                      '\n'
#                                      '\n'
#                                      '"Flock has been helped immeasurably by '
#                                      'the DIT and their fantastic team. Twice '
#                                      'now I have travelled to the USA on Trade '
#                                      'Missions that have been organised and '
#                                      'expertly led by the DIT. The first, a '
#                                      'fundraising trip to San Francisco and '
#                                      'Las Vegas, was one of the catalysts in '
#                                      'Flock’s successful seed fundraise, in '
#                                      'that it led to us meeting a range of '
#                                      'high-profile investors, some of whom '
#                                      'went on to invest. I cannot stress '
#                                      'enough how valuable a resource the DIT '
#                                      'and their Trade Missions have been in '
#                                      'facilitating Flock’s growth, both in the '
#                                      'UK and internationally." -\xa0Ed Leon '
#                                      'Klinger, CEO of Flock, Mission delegate '
#                                      "Fall '17 and Spring '18.\n"
#                                      '\n'
#                                      'About San Francisco FinTech Week\xa0& '
#                                      'the Empire FinTech Conference\xa0\n'
#                                      ' SF FinTech Week is a confluence of '
#                                      'conferences, round-table discussions, '
#                                      'demo days, meetups and networking '
#                                      'events. The diverse events across the '
#                                      'region are all intended to build '
#                                      'partnerships, spur innovation, forecast '
#                                      'future trends, and build on the '
#                                      'tremendous momentum of Bay Area '
#                                      'FinTech.\n'
#                                      'We may attend the Empire FinTech '
#                                      'Conference (negotiations ongoing) where '
#                                      'attendees can hear from those forging '
#                                      'new trails in payments, blockchain, '
#                                      'lending, robo-advisors, insurance tech, '
#                                      'real estate and more. In addition to '
#                                      'attracting hundreds of FinTech '
#                                      'entrepreneurs, this conference also '
#                                      'plays host to the investors and service '
#                                      'providers that help accelerate startups. '
#                                      'The audience can also look forward to '
#                                      'keynotes, panels and demo updates from '
#                                      'some of the top FinTech startups in the '
#                                      'world.\xa0  2018 SF FinTech Mission '
#                                      'Costs and Deadlines\xa0 \n'
#                                      'Cost to attend this mission is £850 per '
#                                      'eligible company that is selected to '
#                                      'attend. This cost represents the time '
#                                      'required to organize the mission and '
#                                      'goes to help reimburse DIT for some of '
#                                      'the costs involved in hosting this '
#                                      'event. In addition to this cost, '
#                                      'delegates are responsible for their own '
#                                      'airfare, hotel, and some meals.\n'
#                                      '\n'
#                                      '\n'
#                                      'Applications must be received no later '
#                                      'than 23.30 PDT on 31 August, 2018\n'
#                                      '\n'
#                                      '\n'
#                                      'Accepted delegates will be notified by '
#                                      '5th September, 2018\xa0and must confirm '
#                                      'their space in the delegation by 10 '
#                                      'September, 2018\n'
#                                      '\n'
#                                      '\n'
#                                      'Acceptance is non-transferable and '
#                                      'completion of the application does not '
#                                      'guarantee acceptance. Selection is '
#                                      'determined through a competitive review '
#                                      'process. For any questions, please '
#                                      'contact max.lelu@mobile.trade.gov.uk'},
#              'end': {'local': '2018-08-31T23:30:00',
#                      'timezone': 'America/Los_Angeles',
#                      'utc': '2018-09-01T06:30:00Z'},
#              'format_id': '10',
#              'hide_end_date': False,
#              'hide_start_date': False,
#              'id': '48209134820',
#              'is_free': True,
#              'is_locked': False,
#              'is_reserved_seating': False,
#              'is_series': False,
#              'is_series_parent': False,
#              'listed': True,
#              'locale': 'en_US',
#              'logo': {'aspect_ratio': '2',
#                       'crop_mask': {'height': 800,
#                                     'top_left': {'x': 0, 'y': 0},
#                                     'width': 1600},
#                       'edge_color': '#99a1ad',
#                       'edge_color_set': True,
#                       'id': '47533160',
#                       'original': {'height': 800,
#                                    'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F47533160%2F232329115819%2F1%2Foriginal.jpg?auto=compress&s=4df3356d40444d8464cb84ad8e2809f7',
#                                    'width': 1600},
#                       'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F47533160%2F232329115819%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C0%2C1600%2C800&s=1fe3c15fe0d767d93e8635ec78f1e0c7'},
#              'logo_id': '47533160',
#              'name': {'html': ' 2018 UK Trade Mission to SF FinTech Week',
#                       'text': ' 2018 UK Trade Mission to SF FinTech Week'},
#              'online_event': False,
#              'organization_id': '17003943201',
#              'organizer_id': '12742539734',
#              'privacy_setting': 'unlocked',
#              'resource_uri': 'https://www.eventbriteapi.com/v3/events/48209134820/',
#              'shareable': True,
#              'show_colors_in_seatmap_thumbnail': False,
#              'show_pick_a_seat': False,
#              'show_seatmap_thumbnail': False,
#              'source': 'create_2.0',
#              'start': {'local': '2018-08-01T00:00:00',
#                        'timezone': 'America/Los_Angeles',
#                        'utc': '2018-08-01T07:00:00Z'},
#              'status': 'started',
#              'subcategory_id': '1002',
#              'tx_time_limit': 10800,
#              'url': 'https://www.eventbrite.com/e/2018-uk-trade-mission-to-sf-fintech-week-registration-48209134820?aff=ebapi',
#              'vanity_url': 'https://ukatsfftw.eventbrite.com',
#              'venue_id': '25855509',
#              'version': '3.0.0'}],
#  'location': {'address': 'san francisco',
#               'augmented_location': {'city': 'San Francisco',
#                                      'country': 'United States',
#                                      'region': 'California'},
#               'latitude': '37.774930',
#               'longitude': '-122.419416',
#               'within': '9.91082317248'},
#  'pagination': {'has_more_items': False,
#                 'object_count': 48,
#                 'page_count': 1,
#                 'page_number': 1,
#                 'page_size': 50}}

# %%
# Create the following variables and set them to empty lists:
    # name_list, start_datetime_list, end_datetime_list, url_list

    


# Loop through each response event and 
    # append the name, times, and url to the appropriate lists declared above.


    

# Print one of the lists to verify correct input.
# Out:
# ['V2 Meetup', 'Women in Leadership and Design Fall Meetup', 'High Growth Handbook - Reader Meetup', 'Group Meditation and Meetup - (Free Format)', 'SF Improv Meetup - Improv Games!', 'People Ops Collective (monthly meetup)', 'San Francisco Thinkific User Meetup (WEWORK SOMA)', 'Gin&Tech: Bitmovin SF Demuxed Meetup', 'BB: San Francisco Music Industry Meetup Sep 6th', 'BB: San Francisco Music Industry Meetup Sep 20th', '[Meetup] Real-Time, Multi-Cloud ML/AI with PipelineAI, TensorFlow, GPU, TPU, Spark, Kafka', 'Project Management, is there no other options ?', 'Know Node: An Intro to Node.js & Express', 'Talent Thought Talk', 'Container Security with NeuVector and IBM Cloud', 'Rincon Game Night', 'Service Design Drinks', '#The100DayProject San Francisco Meet Up', 'Intro to Blockchain, Hyperledger & Ethereum', 'React Native: An Intro to Mobile with React', 'JavaScript: The Tricky Parts', 'Introduction to React.js Props And State', "Let's Network and Find Jobs! Mixer", 'Learn to Code San Francisco: Intro to SQL', 'Getting started with Kubernetes', 'SF Freelancers Union SPARK: The Future of Freelancing', 'Introduction to Serverless Computing with IBM Cloud Functions', 'Oracle OpenWorld Customer Advisory Board Meet Up', 'The Corporate Social Responsibility & Systemic Change Hike', 'Hiking for impact investing, social enterprise & systemic change', 'Augmented Reality for Sustainable Development Goals Hike', 'WebXR Study Group: WebXR for Brain Machine Interfaces', 'Deploying Chatbots & Voice Assistants in Customer Support', "A.D. 'Til Infinity 2019 | A Good Friday Poetic Production", 'Artificial Intelligence for Sustainable Development Goals Hike', 'Hike waste to value', 'WHY YOUR RENTAL PROPERTY IS LEAVING MONEY ON THE TABLE AND HOW TO OUTPERFORM THE MARKET: DANA DUNFORD, Co-Founder Hemlane.com', 'Hike with venture labs, venture builders, & venture replicators for SDGs', 'Intrapreneurship for Systemic Change Hike', 'Galvanize San Francisco: Data Science and Web Development Immersive Programs Info Session', 'Rithm School Private Accelerated Bootcamp Prep', '[San Francisco] Toast the promising new horizons of Seasteading!', 'Partner Event: "Modern Interfaces & Interactions for Augmented Reality"', 'Real World Serverless - San Francisco', 'Blockchain Event', 'Expanding to Asia and Latam Tech: Talent, Opportunities, Blockchain Regulation', ' 2018 UK Trade Mission to SF FinTech Week']

# %%
# Create a variable event_dict and set it to a dictionary for the data frame using 
    # lists created earlier from name, start date time, end date time, and url

    


# Create a new variable "event_data"
    # Set it to a new dataframe by using pandas to create a dataframe from event_dict


# Show all rows of event_data


# See if there's an interesting event you would like to attend?
# Out:
#                                                                                                                              name  \
# 0   V2 Meetup
# 1   Women in Leadership and Design Fall Meetup
# 2   High Growth Handbook - Reader Meetup
# 3   Group Meditation and Meetup - (Free Format)
# 4   SF Improv Meetup - Improv Games!
# 5   People Ops Collective (monthly meetup)
# 6   San Francisco Thinkific User Meetup (WEWORK SOMA)
# 7   Gin&Tech: Bitmovin SF Demuxed Meetup
# 8   BB: San Francisco Music Industry Meetup Sep 6th
# 9   BB: San Francisco Music Industry Meetup Sep 20th
# 10  [Meetup] Real-Time, Multi-Cloud ML/AI with PipelineAI, TensorFlow, GPU, TPU, Spark, Kafka
# 11  Project Management, is there no other options ?
# 12  Know Node: An Intro to Node.js & Express
# 13  Talent Thought Talk
# 14  Container Security with NeuVector and IBM Cloud
# 15  Rincon Game Night
# 16  Service Design Drinks
# 17  #The100DayProject San Francisco Meet Up
# 18  Intro to Blockchain, Hyperledger & Ethereum
# 19  React Native: An Intro to Mobile with React
# 20  JavaScript: The Tricky Parts
# 21  Introduction to React.js Props And State
# 22  Let's Network and Find Jobs! Mixer
# 23  Learn to Code San Francisco: Intro to SQL
# 24  Getting started with Kubernetes
# 25  SF Freelancers Union SPARK: The Future of Freelancing
# 26  Introduction to Serverless Computing with IBM Cloud Functions
# 27  Oracle OpenWorld Customer Advisory Board Meet Up
# 28  The Corporate Social Responsibility & Systemic Change Hike
# 29  Hiking for impact investing, social enterprise & systemic change
# 30  Augmented Reality for Sustainable Development Goals Hike
# 31  WebXR Study Group: WebXR for Brain Machine Interfaces
# 32  Deploying Chatbots & Voice Assistants in Customer Support
# 33  A.D. 'Til Infinity 2019 | A Good Friday Poetic Production
# 34  Artificial Intelligence for Sustainable Development Goals Hike
# 35  Hike waste to value
# 36  WHY YOUR RENTAL PROPERTY IS LEAVING MONEY ON THE TABLE AND HOW TO OUTPERFORM THE MARKET: DANA DUNFORD, Co-Founder Hemlane.com
# 37  Hike with venture labs, venture builders, & venture replicators for SDGs
# 38  Intrapreneurship for Systemic Change Hike
# 39  Galvanize San Francisco: Data Science and Web Development Immersive Programs Info Session
# 40  Rithm School Private Accelerated Bootcamp Prep
# 41  [San Francisco] Toast the promising new horizons of Seasteading!
# 42  Partner Event: "Modern Interfaces & Interactions for Augmented Reality"
# 43  Real World Serverless - San Francisco
# 44  Blockchain Event
# 45  Expanding to Asia and Latam Tech: Talent, Opportunities, Blockchain Regulation
# 46   2018 UK Trade Mission to SF FinTech Week
#
#                   start                  end  \
# 0   2018-08-29T17:30:00  2018-08-29T19:30:00
# 1   2018-10-05T17:30:00  2018-10-05T19:30:00
# 2   2018-08-23T19:00:00  2018-08-23T20:30:00
# 3   2018-08-24T18:30:00  2018-08-24T20:00:00
# 4   2018-09-08T15:30:00  2018-09-08T18:30:00
# 5   2018-09-19T18:00:00  2018-09-19T20:00:00
# 6   2018-09-20T18:00:00  2018-09-20T20:00:00
# 7   2018-10-17T18:30:00  2018-10-17T20:30:00
# 8   2018-09-06T09:00:00  2018-09-06T11:00:00
# 9   2018-09-20T09:00:00  2018-09-20T11:00:00
# 10  2018-09-04T18:00:00  2018-09-04T21:00:00
# 11  2018-08-23T18:00:00  2018-08-23T20:00:00
# 12  2018-09-11T18:30:00  2018-09-11T20:00:00
# 13  2018-08-23T09:00:00  2018-08-23T10:30:00
# 14  2018-09-26T18:00:00  2018-09-26T21:00:00
# 15  2017-09-10T18:00:00  2020-12-31T22:00:00
# 16  2018-08-23T18:00:00  2018-08-23T20:00:00
# 17  2018-09-25T17:30:00  2018-09-25T19:30:00
# 18  2018-08-23T18:00:00  2018-08-23T19:30:00
# 19  2018-08-28T18:30:00  2018-08-28T20:00:00
# 20  2018-09-04T18:30:00  2018-09-04T20:00:00
# 21  2018-09-25T18:30:00  2018-09-25T20:00:00
# 22  2018-08-28T18:00:00  2018-08-28T20:00:00
# 23  2018-09-20T18:30:00  2018-09-20T20:30:00
# 24  2018-09-04T18:00:00  2018-09-04T20:00:00
# 25  2018-09-05T18:30:00  2018-09-05T20:00:00
# 26  2018-09-13T09:30:00  2018-09-13T11:00:00
# 27  2018-10-24T13:30:00  2018-10-24T16:00:00
# 28  2018-10-21T14:00:00  2018-10-21T19:00:00
# 29  2018-10-21T14:00:00  2018-10-21T19:00:00
# 30  2018-10-21T14:00:00  2018-10-21T19:00:00
# 31  2018-08-24T19:00:00  2018-08-24T22:00:00
# 32  2018-09-10T18:00:00  2018-09-10T20:00:00
# 33  2019-04-19T18:00:00  2019-04-19T21:00:00
# 34  2018-10-21T14:00:00  2018-10-21T19:00:00
# 35  2018-10-21T14:00:00  2018-10-21T17:00:00
# 36  2018-08-23T19:00:00  2018-08-23T22:00:00
# 37  2018-10-21T14:00:00  2018-10-21T19:00:00
# 38  2018-10-21T14:00:00  2018-10-21T19:00:00
# 39  2018-08-28T17:30:00  2018-08-28T18:30:00
# 40  2018-09-24T18:00:00  2018-10-03T20:30:00
# 41  2018-09-20T19:00:00  2018-09-20T22:00:00
# 42  2018-09-05T18:00:00  2018-09-05T21:00:00
# 43  2018-09-11T18:00:00  2018-09-11T20:30:00
# 44  2018-10-05T09:00:00  2018-10-12T22:00:00
# 45  2018-09-04T18:00:00  2018-09-04T21:00:00
# 46  2018-08-01T00:00:00  2018-08-31T23:30:00
#
#                                                                                                                                                         url
# 0   https://www.eventbrite.com/e/v2-meetup-tickets-49107100660?aff=ebapi
# 1   https://www.eventbrite.com/e/women-in-leadership-and-design-fall-meetup-tickets-49391290680?aff=ebapi
# 2   https://www.eventbrite.com/e/high-growth-handbook-reader-meetup-tickets-48582823533?aff=ebapi
# 3   https://www.eventbrite.com/e/group-meditation-and-meetup-free-format-tickets-48021422367?aff=ebapi
# 4   https://www.eventbrite.com/e/sf-improv-meetup-improv-games-tickets-49189474041?aff=ebapi
# 5   https://www.eventbrite.com/e/people-ops-collective-monthly-meetup-tickets-49223029406?aff=ebapi
# 6   https://www.eventbrite.ca/e/san-francisco-thinkific-user-meetup-wework-soma-tickets-46867949298?aff=ebapi
# 7   https://www.eventbrite.com/e/gintech-bitmovin-sf-demuxed-meetup-tickets-49315722654?aff=ebapi
# 8   https://www.eventbrite.com/e/bb-san-francisco-music-industry-meetup-sep-6th-tickets-49053817288?aff=ebapi
# 9   https://www.eventbrite.com/e/bb-san-francisco-music-industry-meetup-sep-20th-tickets-49053880477?aff=ebapi
# 10  https://www.eventbrite.com/e/meetup-real-time-multi-cloud-mlai-with-pipelineai-tensorflow-gpu-tpu-spark-kafka-tickets-48092437776?aff=ebapi
# 11  https://www.eventbrite.com/e/project-management-is-there-no-other-options-tickets-45094607184?aff=ebapi
# 12  https://www.eventbrite.com/e/know-node-an-intro-to-nodejs-express-tickets-48572255925?aff=ebapi
# 13  https://www.eventbrite.com/e/talent-thought-talk-registration-42963859059?aff=ebapi
# 14  https://www.eventbrite.com/e/container-security-with-neuvector-and-ibm-cloud-tickets-49261043106?aff=ebapi
# 15  https://www.eventbrite.com/e/rincon-game-night-tickets-36707407845?aff=ebapi
# 16  https://www.eventbrite.com/e/service-design-drinks-tickets-48891468699?aff=ebapi
# 17  https://www.eventbrite.com/e/the100dayproject-san-francisco-meet-up-tickets-48660273187?aff=ebapi
# 18  https://www.eventbrite.com/e/intro-to-blockchain-hyperledger-ethereum-tickets-48287418970?aff=ebapi
# 19  https://www.eventbrite.com/e/react-native-an-intro-to-mobile-with-react-tickets-47685295001?aff=ebapi
# 20  https://www.eventbrite.com/e/javascript-the-tricky-parts-tickets-48571841686?aff=ebapi
# 21  https://www.eventbrite.com/e/introduction-to-reactjs-props-and-state-tickets-48707294830?aff=ebapi
# 22  https://www.eventbrite.com/e/lets-network-and-find-jobs-mixer-tickets-48468354152?aff=ebapi
# 23  https://www.eventbrite.com/e/learn-to-code-san-francisco-intro-to-sql-tickets-48847656656?aff=ebapi
# 24  https://www.eventbrite.com/e/getting-started-with-kubernetes-tickets-48983498964?aff=ebapi
# 25  https://www.eventbrite.com/e/sf-freelancers-union-spark-the-future-of-freelancing-tickets-48691799483?aff=ebapi
# 26  https://www.eventbrite.com/e/introduction-to-serverless-computing-with-ibm-cloud-functions-tickets-47603443180?aff=ebapi
# 27  https://www.eventbrite.com/e/oracle-openworld-customer-advisory-board-meet-up-tickets-48671544901?aff=ebapi
# 28  https://www.eventbrite.com/e/the-corporate-social-responsibility-systemic-change-hike-tickets-46038672910?aff=ebapi
# 29  https://www.eventbrite.com/e/hiking-for-impact-investing-social-enterprise-systemic-change-tickets-46003896894?aff=ebapi
# 30  https://www.eventbrite.com/e/augmented-reality-for-sustainable-development-goals-hike-tickets-46038703000?aff=ebapi
# 31  https://www.eventbrite.com/e/webxr-study-group-webxr-for-brain-machine-interfaces-tickets-49236214844?aff=ebapi
# 32  https://www.eventbrite.com/e/deploying-chatbots-voice-assistants-in-customer-support-tickets-49072427953?aff=ebapi
# 33  https://www.eventbrite.com/e/ad-til-infinity-2019-a-good-friday-poetic-production-registration-42546668230?aff=ebapi
# 34  https://www.eventbrite.com/e/artificial-intelligence-for-sustainable-development-goals-hike-tickets-46038693973?aff=ebapi
# 35  https://www.eventbrite.com/e/hike-waste-to-value-tickets-46044232539?aff=ebapi
# 36  https://www.eventbrite.com/e/why-your-rental-property-is-leaving-money-on-the-table-and-how-to-outperform-the-market-dana-tickets-48722819264?aff=ebapi
# 37  https://www.eventbrite.com/e/hike-with-venture-labs-venture-builders-venture-replicators-for-sdgs-tickets-46044211476?aff=ebapi
# 38  https://www.eventbrite.com/e/intrapreneurship-for-systemic-change-hike-tickets-46038603703?aff=ebapi
# 39  https://www.eventbrite.com/e/galvanize-san-francisco-data-science-and-web-development-immersive-programs-info-session-tickets-45280396886?aff=ebapi
# 40  https://www.eventbrite.com/e/rithm-school-private-accelerated-bootcamp-prep-tickets-48382957729?aff=ebapi
# 41  https://www.eventbrite.com/e/san-francisco-toast-the-promising-new-horizons-of-seasteading-tickets-47136804451?aff=ebapi
# 42  https://www.eventbrite.com/e/partner-event-modern-interfaces-interactions-for-augmented-reality-tickets-49414751853?aff=ebapi
# 43  https://www.eventbrite.com/e/real-world-serverless-san-francisco-tickets-49396619619?aff=ebapi
# 44  https://www.eventbrite.com/e/blockchain-event-tickets-47570477579?aff=ebapi
# 45  https://www.eventbrite.com/e/expanding-to-asia-and-latam-tech-talent-opportunities-blockchain-regulation-tickets-49326107716?aff=ebapi
# 46  https://www.eventbrite.com/e/2018-uk-trade-mission-to-sf-fintech-week-registration-48209134820?aff=ebapi
