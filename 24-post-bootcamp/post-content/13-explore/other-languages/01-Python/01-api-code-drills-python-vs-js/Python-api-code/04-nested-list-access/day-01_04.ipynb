# %%
# Day 01
# Activity 05
# Nested List Access

# %%
print("====================  Foreword  ====================")
list = ["Zero","One","Two","Three","Four","Five"]
# Accessing values in a single-dimensional list is as easy as calling on the index of the index of the target element that you are looking for. 
# For example, if your target element was the string "Three" in the above list then we would access the index where that element was located: 
# list[3] and the value held at that index would be returned : "Three"

# Lists in JS can store any datatype, including a sub-list:

sub_list = ["Zero","One","Two",["Three","Four"],"Five"]

# To access the element "three" we would first need to access the list that is held at index 3: 

#sub_list[3] which would return the sub-list ["Three","Four"] and then access the index of that sub-list in order to return the value of "Three":

print(sub_list[3][0])

# Let us examine a more complicated example: 

nested_list = [[1,2], ["nested", ["Radio Flyer Wagon", "Chemistry Set", ["Joy Buzzer", "Yo-Yo"]]]]

# `nested_list` is a multi-dimensional data structure, and becoming familiar with accessing nested values is a skill that takes practice. 

# Below is a series of sample data structures. We have specified a desired target element and asked for you to provide the code for accessing that value.

# %%
# ------------------------------------------------------------------
print("==================== Question 01 ====================")
# Your target is: "Yo-Yo"
nested_list = [[1,2], ["nested", ["Radio Flyer Wagon", "Chemistry Set", ["Joy Buzzer", "Yo-Yo"]]]]
target = ""
# assign `target` the value of "Yo-Yo" using the `nested_list` variable
# 




# This should print out "Yo-Yo"
print(target)

# %%
# ------------------------------------------------------------------
print("==================== Question 02 ====================")
# Your target is: "Sock Monkey"
nested_list = ["Pop-Up Book", ["Stuffed Mickey Mouse", ["Beach Ball", "Sock Monkey"], "Buck Rogers Rocket Pistol"], "Microscope Set"]
target = ""
# assign `target` the value of "Sock Monkey" using the `nested_list` variable
# 




# This should print out "Sock Monkey"
print(target)

# %%
# ------------------------------------------------------------------
print("==================== Question 03 ====================")
# Your target is: 42
nested_number_list = [3,1,[41,59,265,358,979],32,38,46,[264338,327,9,50,[2,88,42,971],69,3,9,937],510,58,2]
target = ""
# assign `target` the value of 42 using the `nested_number_list` variable
# 




# This should print out 42
print(target)

# %%
# ------------------------------------------------------------------
print("==================== Question 04 ====================")
# Your target is is: "Legos"
nested_mixed_list = [8,[76,["Bubble Solution"],530,"Slinky","Magic 8 Ball","Legos"],9]
target = ""
# assign `target` the value of "Legos" using the `nested_mixed_list` variable
# 




# This should print out "Legos"
print(target)

# %%
# ------------------------------------------------------------------
print("==================== Question 05 ====================")
# Nested Dictionary Access
# It is important to remember the following with lists and dictionaries:
# Lists: Are ordered, integer-indexed collections of any dictionary. This is a data structure where order matters and elements within an list are accessed by index.
# dictionaries: Are dictionary-like collections of unique keys and their values. This is a data structure where order does not matter, and elements within a dictionary are accessed by a key which returns a value.

# Your desired target is: "Value!"
nested_dictionary = {"outer": {"innerKey": {"dictionary": {"key": "Value!"}}}}
target = ""
# assign `target` the value of "Value!" using the `nested_dictionary` variable
# 




# This should print out "Value!"
print(target)

# %%
# ------------------------------------------------------------------
print("==================== Question 06 ====================")
# Nested Mixed DataType Access
# Your target is: "goal"
nested_mixed_data_types = {"list": ["list", {"dictionary": "goal"}]}
target = ""
# assign `target` the value of "goal" using the `nested_mixed_data_types` variable
# 




# This should print out "goal"
print(target)

# %%
# ------------------------------------------------------------------
print("==================== Question 06 ====================")
# Nested Mixed DataType Access
# Your target is: "goal"
nested_mixed_data_types = {"list": ["list", {"dictionary": "goal"}]}
target = ""
# assign `target` the value of "goal" using the `nested_mixed_data_types` variable
# 




# This should print out "goal"
print(target)

# %%
# ------------------------------------------------------------------
print("==================== Question 07 ====================")
# Iterate over the List of dictionaries:
# iterating over nested data structures becomes easier when you have a grasp on how to access nested values. 
# Using the following list of dictionaries, iterate over the list and print the elements in order.
toy_list_of_dictionaries = [  
  {  
     "Product":20,
     "item":"Yo-Yo"
  },
  {  
     "Product":19,
     "item":"Legos"
  },
  {  
     "Product":18,
     "item":"Chemistry Set"
  },
  {  
     "Product":17,
     "item":"Bubble Solution"
  },
  {  
     "Product":16,
     "item":"Tonka Truck"
  },
  {  
     "Product":15,
     "item":"Frisbee"
  },
  {  
     "Product":14,
     "item":"Plarail Toy Train"
  },
  {  
     "Product":13,
     "item":"Etch A Sketch"
  },
  {  
     "Product":12,
     "item":"Koosh Ball"
  },
  {  
     "Product":11,
     "item":"Buzz Lightyear"
  },
  {  
     "Product":10,
     "item":"Furby"
  },
  {  
     "Product":9,
     "item":"Tickle Me Elmo"
  },
  {  
     "Product":8,
     "item":"Beanie Baby"
  },
  {  
     "Product":7,
     "item":"Teddy Ruxpin"
  },
  {  
     "Product":6,
     "item":"Slap Bracelet"
  },
  {  
     "Product":5,
     "item":"Cabbage Patch Kids"
  },
  {  
     "Product":4,
     "item":"Stretch Armstrong"
  },
  {  
     "Product":3,
     "item":"Rubik's Cube"
  },
  {  
     "Product":2,
     "item":"Weebles"
  },
  {  
     "Product":1,
     "item":"NERF Ball"
  }
]
# The output for each element should be formatted like this:

# Count: 20
# Item: Yo-Yo
# *************************
# Count: 19
# Item: Legos
# *************************
# Count: 18
# Item: Chemistry Set
# *************************
# Count: 17
# Item: Bubble Solution
# *************************

def iterate_list_dictionaries(list_of_dics):
  # ---------- Your Code Here ----------






  # ---------- End of Code Area ----------

# Calling the function
iterate_list_dictionaries(toy_list_of_dictionaries)

# %%
# ------------------------------------------------------------------
print("==================== Question 08  ====================")
# Using the `toy_list_of_dictionaries` variable from question 7, iterate through the
# list again, but print all the elements in reverse order. Your output should
# look like the following: 

# Count: 1
# Item: NERF Ball
# *************************
# Count: 2
# Item: Weebles
# *************************
# Count: 3
# Item: Rubik's Cube
# *************************
# Count: 4
# Item: Stretch Armstrong
# *************************

def iterate_list_dictionaries_reverse(list_of_dics):
  # ---------- Your Code Here ----------



  


  # ---------- End of Code Area ----------

# Calling the function
iterate_list_dictionaries_reverse(toy_list_of_dictionaries)
