# %%
# Dependencies json, requests, pprint, and your config file for api_key

# %%
# Set the url and query information for the country of US



# Build query URL with the country query.
# Out:
# 'https://newsapi.org/v2/top-headlines?country=us&apiKey=api_key'

# %%
# Get news data using requests


# Test your api call using by printing your api data.
# Out:
# The news API responded with: {'status': 'ok', 'totalResults': 20, 'articles': [{'source': {'id': 'reuters', 'name': 'Reuters'}, 'author': 'Michael Martina', 'title': 'US-China trade war escalates as new tariffs kick in', 'description': "The United States and China escalated their acrimonious trade war on Thursday, implementing punitive 25 percent tariffs on $16 billion worth of each other's goods, even as mid-level officials from both sides resumed talks in Washington.", 'url': 'https://www.reuters.com/article/us-usa-trade-china/us-china-trade-war-escalates-as-new-tariffs-kick-in-idUSKCN1L809K', 'urlToImage': 'https://s3.reutersmedia.net/resources/r/?m=02&d=20180823&t=2&i=1296493959&w=1200&r=LYNXNPEE7M06P', 'publishedAt': '2018-08-23T06:13:51Z'}, {'source': {'id': 'cnn', 'name': 'CNN'}, 'author': 'Analysis by Stephen Collinson, CNN', 'title': 'Legal stunner fails to fell Trump but reckoning could be coming', 'description': 'After one day where truth and facts triumphed, America is ba
# ...

# %%
# Create variable called articles_list 
    # Set it to a list of all article dictionaries from news_json


# Use pprint to print the articles_list
# Out:
# [{'author': 'Michael Martina',
#   'description': 'The United States and China escalated their acrimonious '
#                  'trade war on Thursday, implementing punitive 25 percent '
#                  "tariffs on $16 billion worth of each other's goods, even as "
#                  'mid-level officials from both sides resumed talks in '
#                  'Washington.',
#   'publishedAt': '2018-08-23T06:13:51Z',
#   'source': {'id': 'reuters', 'name': 'Reuters'},
#   'title': 'US-China trade war escalates as new tariffs kick in',
#   'url': 'https://www.reuters.com/article/us-usa-trade-china/us-china-trade-war-escalates-as-new-tariffs-kick-in-idUSKCN1L809K',
#   'urlToImage': 'https://s3.reutersmedia.net/resources/r/?m=02&d=20180823&t=2&i=1296493959&w=1200&r=LYNXNPEE7M06P'},
#  {'author': 'Analysis by Stephen Collinson, CNN',
#   'description': 'After one day where truth and facts triumphed, America is '
#                  'back to its alternative realities.',
# ...
