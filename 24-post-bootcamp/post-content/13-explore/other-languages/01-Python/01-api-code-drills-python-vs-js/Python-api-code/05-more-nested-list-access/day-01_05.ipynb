# %%
# Day 01
# More Nested List Access

# %%
# ------------------------------------------------------------------
print("==================== Question 01  ====================")
# Constructing a Custom Dictionary:
# So far you have learned about lists and dictionaries and played with enumerators (loops!). 
toy_list = ["Water Balloon","Silly Putty","Paint-by-Numbers Kit",
             "Mr. Potato Head","Wiffle Ball","PEZ Dispenser",
             "Mr. Potato Head","Gumby","Hula Hoop","Mr. Potato Head",
             "Troll Doll","Silly Putty","Slip n Slide"]

# For this challenge, iterate over the provided `toy_list` and create your own custom `toy_inventory_obj`. 
#`toy_inventory_obj` will be an dictionary with key-value pairs. 

#What the `toy_inventory_obj` should store is the name of the toy as the key and how many times it occurs in the toy_list as the value. 
# For example "Water Balloon" occurs once in the toy_list and "Silly Putty" occurs twice. What I would expect the function to construct is:

# toy_inventory_obj = {
#   "Water Balloon":1,
#   "Silly Putty":2,
#   ...
# }

def return_custom_dictionary(list):
    dic ={}
  
  # ---------- Your Code Here ----------






  # ---------- End of Code Area ----------

    return dic


# calling on your function and storing the return value
toy_inventory_obj = return_custom_dictionary(toy_list)
print(toy_inventory_obj)
# This is what I would expect as the return value of the `toy_inventory_obj`:

# { 'Water Balloon': 1,
#   'Silly Putty': 2,
#   'Paint-by-Numbers Kit': 1,
#   'Mr. Potato Head': 3,
#   'Wiffle Ball': 1,
#   'PEZ Dispenser': 1,
#   'Gumby': 1,
#   'Hula Hoop': 1,
#   'Troll Doll': 1,
#   'Slip n Slide': 1 }
# Out:
# ==================== Question 01  ====================
# {}

# %%
# ------------------------------------------------------------------
print("==================== Question 02  ====================")
# Evaluating Values in a Dictionary:

# Iterate over the custom dictionary you created in the previous question (`toy_inventory_obj`) and look at each of its keys and values. 
# Return the toy that occurs the greatest number of times using the `toy_inventory_obj`.

def greatest_frequency(toy_inventory):
    max_toy = ""
    max_num = 0
  
  # ---------- Your Code Here ----------






  # ---------- End of Code Area ----------

    print("The toy that occurs the greatest number of times is "+ max_toy + ", which occurs " + str(max_num) +" times.")


# The print of your application should be the following string: 
# "The toy that occurs the greatest number of times is 'Mr. Potato Head', which occurs 3 times."
greatest_frequency(toy_inventory_obj)
# Out:
# ==================== Question 02  ====================
# The toy that occurs the greatest number of times is , which occurs 0 times.

# %%
# ------------------------------------------------------------------
print("==================== Question 03  ====================")
# Custom dic Creation from an List of Values

# Dictionary creation from an list of elements:
toy_list = ["Iron Man vs. Ultron","Iron Man vs. Loki","Park Animals", "Adventure Camp Rafting","Snax"]
# Using the names given in the `toy_list`, construct toy dictionaries and create a new list, `toy_list_of_dics`, filled with those 5 new `Toy Dictionaries`.
# The names of the toys should be stored within the `name` key.

def toy_list_to_dic(list_of_toys):
  
    toy_list_of_dics = []

  # ---------- Your Code Here ----------






  # ---------- End of Code Area ----------

    return toy_list_of_dics


new_toy_list = toy_list_to_dic(toy_list)
print(new_toy_list)
# The new_toy_list should look like this:

# [ { name: 'Iron Man vs. Ultron' },
#   { name: 'Iron Man vs. Loki' },
#   { name: 'Park Animals' },
#   { name: 'Adventure Camp Rafting' },
#   { name: 'Snax' } ]
# Out:
# ==================== Question 03  ====================
# []

# %%
# ------------------------------------------------------------------
print("==================== Question 04  ====================")
# Constructing a Custom Dictionary With Calculated Values:

# Please iterate over the provided toy_inventory_list_of_dics and create a custom dictionary that holds the following values:
# Requirements: 
# A key for each toy_line with the following key value pairs
# - toy_line, which contains the name of the toy_line
# - An list holding the names of each toy in that line
# - number of total number of toys in stock for that line

# The desired Dictionary that you should expect is a Dictionary that looks like this:

# { 'Potato Head Series': 
#    { 'toy_line': 'Potato Head Series',
#      'toy_line_toys': 
#       [ 'Mr. Potato Head',
#         'Potato Bug',
#         'Johnny Rotten Apple',
#         'Dr. Fruitcake',
#         'Ham Monster',
#         'Mr. Giblets',
#         'Aliens' ],
#      'total_toys_in_toy_line': 1930 },
#   'Adventure Time Series': 
#    { 'toy_line': 'Adventure Time Series',
#      'toy_line_toys': [ 'Finn the Human', 'Jake the Dog', 'Princess Bubblegum' ],
#      'total_toys_in_toy_line': 116 } }

# DATA SET

# Here is the provided list that contains each of the toy dictionaries that contain the information that you need:  

toy_inventory_list_of_dics = [
 {  "title": "Mr. Potato Head", #name of toy
    "toy_line" : "Potato Head Series", #name of toyline
    "full_price": "05.00", #full price for this toy
    "stock": 3 #number of toys in stock for this toy
 },
 {  "title": "Potato Bug",
    "toy_line": "Potato Head Series",
    "full_price": "10.00",
    "stock": 1
 },
 {  "title": "Johnny Rotten Apple",
    "toy_line": "Potato Head Series",
    "full_price": "15.00",
    "stock": 59
 },
 {  "title": "Dr. Fruitcake",
    "toy_line": "Potato Head Series",
    "full_price": "20.00",
    "stock": 265
 },
 {  "title": "Ham Monster",
    "toy_line": "Potato Head Series",
    "full_price": "25.00",
    "stock": 265
 },
 {  "title": "Mr. Giblets",
    "toy_line": "Potato Head Series",
    "full_price": "30.00",
    "stock": 358
 },
 {  "title": "Aliens",
    "toy_line": "Potato Head Series",
    "full_price": "35.00",
    "in_stock": False,
    "stock": 979
 },
 {  "title": "Finn the Human",
    "toy_line": "Adventure Time Series",
    "full_price": "40.00",
    "stock": 32
 },
 {  "title": "Jake the Dog",
    "toy_line": "Adventure Time Series",
    "full_price": "45.00",
    "stock": 38
 },
 {  "title": "Princess Bubblegum",
    "toy_line": "Adventure Time Series",
    "full_price": "50.00",
    "stock": 46
 }]

# Iterate over each dictionary in the provided `toy_inventory_list_of_dics` and create a custom dictionary: `custom_toy_line_dic`.
# We can to consolidate the list of toy dictionaries into a toyline dictionary as defined by the instructions above
def create_custom_dictionary(dictionary_list):

    custom_toy_line_dic = {}

  # ---------- Your Code Here ----------






  # ---------- End of Code Area ----------

    return custom_toy_line_dic


# The following should print the `custom_toy_line_dic` to terminal
custom_dictionary = create_custom_dictionary(toy_inventory_list_of_dics)# takes the `toy_inventory_list_of_dics` as an argument
print(custom_dictionary)

# This is a tester function that will perform a quick spot check to test if your code is working
def test_dictionary(dictionary):
    if ((dictionary['Potato Head Series'] != 0) & (dictionary['Adventure Time Series'] != 0)):
        if (int((dictionary['Potato Head Series']['total_toys_in_toy_line']) == 1930) &
          (len(dictionary['Potato Head Series']['toy_line_toys']) == 7) &
          (int(dictionary['Adventure Time Series']['total_toys_in_toy_line']) == 116) &
          (len(dictionary['Adventure Time Series']['toy_line_toys']) == 3)):
          return True
    return False


# We're going to test your code with the tester function
# This should print `True` if the dictionary you made matches up enough with ours
print(test_dictionary(custom_dictionary))
# Out:
# ==================== Question 04  ====================
# {}
# True

# %%
# ------------------------------------------------------------------
print("==================== Question 05  ====================")
# Write a function that when passed an list of numbers, returns true if there are
# duplicate numbers within that list and false if there are no duplicates within
# the argument

def are_dups(list):
    print('--------------------')
  # ---------- Your Code Here ----------






  # ---------- End of Code Area ----------



# These lists are going to be used to test your function
duplicates_one = [1,2,4,5,77,8,19,4]
duplicates_two = [32,4,60,56,78,3,9]

# This should print true:
print(are_dups(duplicates_one))

# This should print false:
print(are_dups(duplicates_two))
# Out:
# ==================== Question 05  ====================
# [1, 2, 4, 5, 77, 8, 19, 4]
# None
# [32, 4, 60, 56, 78, 3, 9]
# None
