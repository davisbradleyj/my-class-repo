# %%
# Import your dependencies requests, json, and pprint for pretty printing.
import requests
import json
from pprint import pprint

# %%
# Create a variable called search_tv
    # Request for user input with the question "What show would you like?"
        # Example "friends" as an input
search_tv = input("What show would you like?")
# Out:
# What show would you like?friends

# %%
# Create a variable called base_url and 
    # set it to the string below
    # "http://api.tvmaze.com/search/shows?q="
    
base_url = "http://api.tvmaze.com/search/shows?q="

# %%
# Set the variable 'response' to the data from base_url with search_tv appended
response = requests.get(base_url + search_tv)
# Out:
# [{'score': 19.10824, 'show': {'id': 431, 'url': 'http://www.tvmaze.com/shows/431/friends', 'name': 'Friends', 'type': 'Scripted', 'language': 'English', 'genres': ['Comedy', 'Romance'], 'status': 'Ended', 'runtime': 30, 'premiered': '1994-09-22', 'officialSite': None, 'schedule': {'time': '20:00', 'days': ['Thursday']}, 'rating': {'average': 8.7}, 'weight': 91, 'network': {'id': 1, 'name': 'NBC', 'country': {'name': 'United States', 'code': 'US', 'timezone': 'America/New_York'}}, 'webChannel': None, 'externals': {'tvrage': 3616, 'thetvdb': 79168, 'imdb': 'tt0108778'}, 'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/41/104550.jpg', 'original': 'http://static.tvmaze.com/uploads/images/original_untouched/41/104550.jpg'}, 'summary': '<p>Six young (20-something) people from New York City (Manhattan), on their own and struggling to survive in the real world, find the companionship, comfort and support they get from each other to be the perfect antidote to the pressures of life.</p><p>This average group of buddies goes through massive mayhem, family trouble, past and future romances, fights, laughs, tears and surprises as they learn what it really means to be a friend.</p>', 'updated': 1532606311, '_links': {'self': {'href': 'http://api.tvmaze.com/shows/431'}, 'previousepisode': {'href': 'http://api.tvmaze.com/episodes/40881'}}}}, {'score': 13.93246, 'show': {'id': 33940, 'url': 'http://www.tvmaze.com/shows/33940/lego-friends', 'name': 'LEGO Friends', 'type': 'Animation', 'language': 'English', 'genres': ['Comedy', 'Children'], 'status': 'Running', 'runtime': 30, 'premiered': '2012-05-05', 'officialSite': None, 'schedule': {'time': '', 'days': []}, 'rating': {'average': None}, 'weight': 80, 'network': {'id': 78, 'name': 'Disney Channel', 'country': {'name': 'United States', 'code': 'US', 'timezone': 'America/New_York'}}, 'webChannel': None, 'externals': {'tvrage': None, 'thetvdb': 270112, 'imdb': 'tt4049416'}, 'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/138/346444.jpg', 'original': 'http://static.tvmaze.com/uploads/images/original_untouched/138/346444.jpg'}, 'summary': '<p>As a way to make friends, new girl in town Olivia volunteers to work at the Heartlake City World Petacular with four other girls.</p>', 'updated': 1534417943, '_links': {'self': {'href': 'http://api.tvmaze.com/shows/33940'}, 'previousepisode': {'href': 'http://api.tvmaze.com/episodes/1514310'}, 'nextepisode': {'href': 'http://api.tvmaze.com/episodes/1514311'}}}}, {'score': 13.867294, 'show': {'id': 6458, 'url': 'http://www.tvmaze.com/shows/6458/thomas-friends', 'name': 'Thomas & Friends', 'type': 'Animation', 'language': 'English', 'genres': ['Children'], 'status': 'Running', 'runtime': 15, 'premiered': '1984-10-09', 'officialSite': 'http://www.channel5.com/show/thomas-and-friends', 'schedule': {'time': '07:20', 'days': ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']}, 'rating': {'average': None}, 'weight': 63, 'network': {'id': 135, 'name': 'Channel 5', 'country': {'name': 'United Kingdom', 'code': 'GB', 'timezone': 'Europe/London'}}, 'webChannel': None, 'externals': {'tvrage': 6340, 'thetvdb': 78949, 'imdb': 'tt0086815'}, 'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/24/61753.jpg', 'original': 'http://static.tvmaze.com/uploads/images/original_untouched/24/61753.jpg'}, 'summary': "<p><b>Thomas &amp; Friends</b> is a British children's television series, which had its first broadcast on the ITV network on 9 October 1984. It is based on The Railway Series of books by the Reverend Wilbert Awdry and his son, Christopher Awdry. These books deal with the adventures of a group of anthropomorphised locomotives and road vehicles who live on the fictional Island of Sodor. The books were based on stories Wilbert told to entertain his son, Christopher during his recovery from measles. From Series one to four, many of the stories are based on events from Awdry's personal exper ...

# %%
# Create a variable called res_data 
    # Set it to the response converted as a json format
res_data = response.json()

# Using pprint, print the res_data
pprint(res_data)
# Out:
# [{'score': 19.10824,
#   'show': {'_links': {'previousepisode': {'href': 'http://api.tvmaze.com/episodes/40881'},
#                       'self': {'href': 'http://api.tvmaze.com/shows/431'}},
#            'externals': {'imdb': 'tt0108778', 'thetvdb': 79168, 'tvrage': 3616},
#            'genres': ['Comedy', 'Romance'],
#            'id': 431,
#            'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/41/104550.jpg',
#                      'original': 'http://static.tvmaze.com/uploads/images/original_untouched/41/104550.jpg'},
#            'language': 'English',
#            'name': 'Friends',
#            'network': {'country': {'code': 'US',
#                                    'name': 'United States',
#                                    'timezone': 'America/New_York'},
#                        'id': 1,
#                        'name': 'NBC'},
#            'officialSite': None,
#            'premiered': '1994-09-22',
#            'rating': {'average': 8.7},
#            'runtime': 30,
#            'schedule': {'days': ['Thursday'], 'time': '20:00'},
#            'status': 'Ended',
#            'summary': '<p>Six young (20-something) people from New York City '
#                       '(Manhattan), on their own and struggling to survive in '
#                       'the real world, find the companionship, comfort and '
#                       'support they get from each other to be the perfect '
#                       'antidote to the pressures of life.</p><p>This average '
#                       'group of buddies goes through massive mayhem, family '
#                       'trouble, past and future romances, fights, laughs, '
#                       'tears and surprises as they learn what it really means '
#                       'to be a friend.</p>',
#            'type': 'Scripted',
#            'updated': 1532606311,
#            'url': 'http://www.tvmaze.com/shows/431/friends',
#            'webChannel': None,
#            'weight': 91}},
#  {'score': 13.93246,
#   'show': {'_links': {'nextepisode': {'href': 'http://api.tvmaze.com/episodes/1514311'},
#                       'previousepisode': {'href': 'http://api.tvmaze.com/episodes/1514310'},
#                       'self': {'href': 'http://api.tvmaze.com/shows/33940'}},
#            'externals': {'imdb': 'tt4049416',
#                          'thetvdb': 270112,
#                          'tvrage': None},
#            'genres': ['Comedy', 'Children'],
#            'id': 33940,
#            'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/138/346444.jpg',
#                      'original': 'http://static.tvmaze.com/uploads/images/original_untouched/138/346444.jpg'},
#            'language': 'English',
#            'name': 'LEGO Friends',
#            'network': {'country': {'code': 'US',
#                                    'name': 'United States',
#                                    'timezone': 'America/New_York'},
#                        'id': 78,
#                        'name': 'Disney Channel'},
#            'officialSite': None,
#            'premiered': '2012-05-05',
#            'rating': {'average': None},
#            'runtime': 30,
#            'schedule': {'days': [], 'time': ''},
#            'status': 'Running',
#            'summary': '<p>As a way to make friends, new girl in town Olivia '
#                       'volunteers to work at the Heartlake City World '
#                       'Petacular with four other girls.</p>',
#            'type': 'Animation',
#            'updated': 1534417943,
#            'url': 'http://www.tvmaze.com/shows/33940/lego-friends',
#            'webChannel': None,
#            'weight': 80}},
#  {'score': 13.867294,
#   'show': {'_links': {'previousepisode': {'href': 'http://api.tvmaze.com/episodes/1327333'},
#                       'self': {'href': 'http://api.tvmaze.com/shows/6458'}},
#            'externals': {'imdb': 'tt0086815', 'thetvdb': 78949, 'tvrage': 6340},
#            'genres': ['Children'],
#            'id': 6458,
#            'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/24/61753.jpg',
#                      'original': 'http://static.tvmaze.com/uploads/images/original_untouched/24/61753.jpg'},
#            'language': 'English',
#            'name': 'Thomas & Friends',
#            'network': {'country': {'code': 'GB',
#                                    'name': 'United Kingdom',
#                                    'timezone': 'Europe/London'},
#                        'id': 135,
#                        'name': 'Channel 5'},
#            'officialSite': 'http://www.channel5.com/show/thomas-and-friends',
#            'premiered': '1984-10-09',
#            'rating': {'average': None},
#            'runtime': 15,
#            'schedule': {'days': ['Monday',
#                                  'Tuesday',
#                                  'Wednesday',
#                                  'Thursday',
#                                  'Friday'],
#                         'time': '07:20'},
#            'status': 'Running',
#            'summary': "<p><b>Thomas &amp; Friends</b> is a British children's "
#                       'television series, which had its first broadcast on the '
#                       'ITV network on 9 October 1984. It is based on The '
#                       'Railway Series of books by the Reverend Wilbert Awdry '
#                       'and his son, Christopher Awdry. These books deal with '
#                       'the adventures of a group of anthropomorphised '
#                       'locomotives and road vehicles who live on the fictional '
#                       'Island of Sodor. The books were based on stories '
#                       'Wilbert told to entertain his son, Christopher during '
#                       'his recovery from measles. From Series one to four, '
#                       "many of the stories are based on events from Awdry's "
#                       'personal experience.</p>',
#            'type': 'Animation',
#            'updated': 1513725505,
#            'url': 'http://www.tvmaze.com/shows/6458/thomas-friends',
#            'webChannel': None,
#            'weight': 63}},
#  {'score': 13.819245,
#   'show': {'_links': {'previousepisode': {'href': 'http://api.tvmaze.com/episodes/1511358'},
#                       'self': {'href': 'http://api.tvmaze.com/shows/33879'}},
#            'externals': {'imdb': None, 'thetvdb': 343514, 'tvrage': None},
#            'genres': [],
#            'id': 33879,
#            'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/147/369465.jpg',
#                      'original': 'http://static.tvmaze.com/uploads/images/original_untouched/147/369465.jpg'},
#            'language': 'English',
#            'name': 'Jane & Friends',
#            'network': {'country': {'code': 'GB',
#                                    'name': 'United Kingdom',
#                                    'timezone': 'Europe/London'},
#                        'id': 135,
#                        'name': 'Channel 5'},
#            'officialSite': 'http://www.channel5.com/show/jane-mcdonald-friends/',
#            'premiered': '2018-03-09',
#            'rating': {'average': None},
#            'runtime': 60,
#            'schedule': {'days': ['Friday'], 'time': '21:00'},
#            'status': 'Running',
#            'summary': '<p><b>Jane &amp; Friends</b> is a variety show in which '
#                       'Jane McDonald performs her favourite songs with her '
#                       'live band. The audience is an integral part of the '
#                       'programme, joining in the songs and sharing the banter. '
#                       'Jane is joined by guest artists and groups performing '
#                       'current songs, classic hits and occasionally duets with '
#                       'Jane herself.</p>',
#            'type': 'Variety',
#            'updated': 1533933656,
#            'url': 'http://www.tvmaze.com/shows/33879/jane-friends',
#            'webChannel': None,
#            'weight': 82}},
#  {'score': 12.759959,
#   'show': {'_links': {'previousepisode': {'href': 'http://api.tvmaze.com/episodes/1260315'},
#                       'self': {'href': 'http://api.tvmaze.com/shows/30774'}},
#            'externals': {'imdb': 'tt0315608', 'thetvdb': 99721, 'tvrage': None},
#            'genres': ['Drama', 'Romance'],
#            'id': 30774,
#            'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/122/305714.jpg',
#                      'original': 'http://static.tvmaze.com/uploads/images/original_untouched/122/305714.jpg'},
#            'language': 'Japanese',
#            'name': 'Friends',
#            'network': {'country': {'code': 'JP',
#                                    'name': 'Japan',
#                                    'timezone': 'Asia/Tokyo'},
#                        'id': 159,
#                        'name': 'TBS'},
#            'officialSite': 'http://www.tbs.co.jp/friends21/',
#            'premiered': '2002-02-04',
#            'rating': {'average': None},
#            'runtime': 65,
#            'schedule': {'days': ['Monday', 'Tuesday'], 'time': '21:00'},
#            'status': 'Ended',
#            'summary': '<p>Left alone on a trip to Hong Kong, Tomoko finds '
#                       'herself the victim of a purse-snatching. The police '
#                       'arrest the man she points out, but it turns out to be '
#                       'the wrong person: a young Korean man named Ji Hoon. '
#                       'Despite his anger and humiliation, he takes her out to '
#                       'dinner since she has lost all her money, and in return, '
#                       'she agrees to model for his amateur film. What follows '
#                       'is a magical and romantic two days. Upon returning to '
#                       'their respective countries, Tomoko must return to her '
#                       'nine-to-five job and Ji Hoon must resume studying to '
#                       'join the family business rather than pursuing his dream '
#                       'of becoming a film director. But soon the two begin to '
#                       'email each other and rekindle their relationship '
#                       'despite the distance and obstacles between them. '
#                       'Marking the very first time in television history that '
#                       'a drama has been co-produced between Japan and South '
#                       'Korea, the story shows us that love has no borders.</p>',
#            'type': 'Scripted',
#            'updated': 1505768726,
#            'url': 'http://www.tvmaze.com/shows/30774/friends',
#            'webChannel': None,
#            'weight': 0}},
#  {'score': 12.630199,
#   'show': {'_links': {'previousepisode': {'href': 'http://api.tvmaze.com/episodes/900444'},
#                       'self': {'href': 'http://api.tvmaze.com/shows/20279'}},
#            'externals': {'imdb': None, 'thetvdb': 254222, 'tvrage': None},
#            'genres': ['Children'],
#            'id': 20279,
#            'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/71/179567.jpg',
#                      'original': 'http://static.tvmaze.com/uploads/images/original_untouched/71/179567.jpg'},
#            'language': 'English',
#            'name': 'Super Friends',
#            'network': {'country': {'code': 'US',
#                                    'name': 'United States',
#                                    'timezone': 'America/New_York'},
#                        'id': 3,
#                        'name': 'ABC'},
#            'officialSite': None,
#            'premiered': '1973-09-08',
#            'rating': {'average': None},
#            'runtime': 35,
#            'schedule': {'days': ['Wednesday'], 'time': ''},
#            'status': 'Ended',
#            'summary': '<p><b>Super Friends</b> first aired on ABC on September '
#                       '8, 1973, featuring well-known DC characters Superman, '
#                       'Batman and Robin, Wonder Woman, and Aquaman as part of '
#                       'its Saturday morning cartoon lineup. It was produced by '
#                       'Hanna-Barbera and was based on the Justice League of '
#                       'America (JLA) and associated comic book characters '
#                       'published by DC Comics. The name of the program (and '
#                       'the JLA members featured with the Super Friends) have '
#                       'been variously represented (as Super Friends and '
#                       'Challenge of the Super Friends, for example) at '
#                       'different points in its broadcast history.</p>',
#            'type': 'Animation',
#            'updated': 1533720501,
#            'url': 'http://www.tvmaze.com/shows/20279/super-friends',
#            'webChannel': None,
#            'weight': 53}},
#  {'score': 12.21648,
#   'show': {'_links': {'previousepisode': {'href': 'http://api.tvmaze.com/episodes/903483'},
#                       'self': {'href': 'http://api.tvmaze.com/shows/7403'}},
#            'externals': {'imdb': 'tt2354667',
#                          'thetvdb': 262928,
#                          'tvrage': None},
#            'genres': ['Comedy', 'Adventure'],
#            'id': 7403,
#            'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/27/68210.jpg',
#                      'original': 'http://static.tvmaze.com/uploads/images/original_untouched/27/68210.jpg'},
#            'language': 'English',
#            'name': 'Battlefield Friends',
#            'network': None,
#            'officialSite': 'https://www.youtube.com/show/battlefieldfriends',
#            'premiered': '2012-03-20',
#            'rating': {'average': None},
#            'runtime': 3,
#            'schedule': {'days': [], 'time': ''},
#            'status': 'Running',
#            'summary': '<p><b>Battlefield Friends</b> is a series of animated '
#                       'shorts set in the game world of Battlefield 3 and '
#                       'Battlefield 4. It chronicles the misadventures of four '
#                       'friends and squadmembers, embodying the four soldier '
#                       'classes available in the games. The series often '
#                       'comically attacks/parodies player trends and game '
#                       'mechanics, such as spawnkilling, buggy bipods, Closet '
#                       'Colonels, etc.</p><p>The series follows four players-a '
#                       'medic, an engineer, a sniper, and a noob. The series '
#                       'incorporates surreal humor mixed with cartoon comedy '
#                       'gags.</p>',
#            'type': 'Animation',
#            'updated': 1477294594,
#            'url': 'http://www.tvmaze.com/shows/7403/battlefield-friends',
#            'webChannel': {'country': None, 'id': 21, 'name': 'YouTube'},
#            'weight': 64}},
#  {'score': 12.134688,
#   'show': {'_links': {'previousepisode': {'href': 'http://api.tvmaze.com/episodes/379663'},
#                       'self': {'href': 'http://api.tvmaze.com/shows/6452'}},
#            'externals': {'imdb': 'tt0094469', 'thetvdb': 77054, 'tvrage': 3644},
#            'genres': ['Children'],
#            'id': 6452,
#            'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/24/61750.jpg',
#                      'original': 'http://static.tvmaze.com/uploads/images/original_untouched/24/61750.jpg'},
#            'language': 'English',
#            'name': 'Garfield and Friends',
#            'network': {'country': {'code': 'US',
#                                    'name': 'United States',
#                                    'timezone': 'America/New_York'},
#                        'id': 2,
#                        'name': 'CBS'},
#            'officialSite': None,
#            'premiered': '1988-09-17',
#            'rating': {'average': None},
#            'runtime': 30,
#            'schedule': {'days': ['Monday',
#                                  'Tuesday',
#                                  'Wednesday',
#                                  'Thursday',
#                                  'Friday',
#                                  'Saturday',
#                                  'Sunday'],
#                         'time': '02:00'},
#            'status': 'Ended',
#            'summary': '<p>An animated television series based on the comic '
#                       'strip Garfield by Jim Davis.</p>',
#            'type': 'Animation',
#            'updated': 1505357449,
#            'url': 'http://www.tvmaze.com/shows/6452/garfield-and-friends',
#            'webChannel': None,
#            'weight': 0}},
#  {'score': 11.837498,
#   'show': {'_links': {'nextepisode': {'href': 'http://api.tvmaze.com/episodes/1514622'},
#                       'previousepisode': {'href': 'http://api.tvmaze.com/episodes/1514621'},
#                       'self': {'href': 'http://api.tvmaze.com/shows/4867'}},
#            'externals': {'imdb': None, 'thetvdb': 264210, 'tvrage': None},
#            'genres': ['Nature'],
#            'id': 4867,
#            'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/82/206116.jpg',
#                      'original': 'http://static.tvmaze.com/uploads/images/original_untouched/82/206116.jpg'},
#            'language': 'English',
#            'name': 'Unlikely Animal Friends',
#            'network': {'country': {'code': 'US',
#                                    'name': 'United States',
#                                    'timezone': 'America/New_York'},
#                        'id': 5,
#                        'name': 'The CW'},
#            'officialSite': 'http://channel.nationalgeographic.com/wild/unlikely-animal-friends/',
#            'premiered': '2012-11-23',
#            'rating': {'average': None},
#            'runtime': 30,
#            'schedule': {'days': ['Saturday'], 'time': '11:30'},
#            'status': 'Running',
#            'summary': '<p>Friends are there for you when you need a shoulder '
#                       'to lean on. But who says only humans have friends? Join '
#                       'us for <b>Unlikely Animal Friends.</b></p>',
#            'type': 'Reality',
#            'updated': 1534697847,
#            'url': 'http://www.tvmaze.com/shows/4867/unlikely-animal-friends',
#            'webChannel': None,
#            'weight': 76}},
#  {'score': 11.70048,
#   'show': {'_links': {'previousepisode': {'href': 'http://api.tvmaze.com/episodes/1199565'},
#                       'self': {'href': 'http://api.tvmaze.com/shows/20345'}},
#            'externals': {'imdb': None, 'thetvdb': 328972, 'tvrage': None},
#            'genres': ['Comedy'],
#            'id': 20345,
#            'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/116/292483.jpg',
#                      'original': 'http://static.tvmaze.com/uploads/images/original_untouched/116/292483.jpg'},
#            'language': 'English',
#            'name': 'Friends from College',
#            'network': None,
#            'officialSite': 'https://www.netflix.com/title/80117485',
#            'premiered': '2017-07-14',
#            'rating': {'average': 5.1},
#            'runtime': 30,
#            'schedule': {'days': ['Friday'], 'time': ''},
#            'status': 'Running',
#            'summary': '<p>As they face down their forties, a group of friends '
#                       'who met at Harvard experiences a range of success -- or '
#                       'lack thereof -- in this comedy series.</p>',
#            'type': 'Scripted',
#            'updated': 1533812914,
#            'url': 'http://www.tvmaze.com/shows/20345/friends-from-college',
#            'webChannel': {'country': None, 'id': 1, 'name': 'Netflix'},
#            'weight': 81}}]

# %%
# Print the following keys from the response JSON.
    # "Show name:" Name
    # "Show score:" Score
    # "Show rating:" Rating

print(f"Show name: {res_data[0]['show']['name']}")
print(f"Show score: {res_data[0]['score']}")
print(f"Show rating: {res_data[0]['show']['rating']['average']}")
# Out:
# Show name: Friends
# Show score: 19.10824
# Show rating: 8.7

# %%
# Loop through each item from the response and print the show's name and rating.
    # "Show name: " Name
    # "Show rating:" Rating
    
for show in res_data:
    print(f"Show name: {show['show']['name']}")
    print(f"Show rating: {show['show']['rating']['average']}")
# Out:
# Show name: Friends
# Show rating: 8.7
# Show name: LEGO Friends
# Show rating: None
# Show name: Thomas & Friends
# Show rating: None
# Show name: Jane & Friends
# Show rating: None
# Show name: Friends
# Show rating: None
# Show name: Super Friends
# Show rating: None
# Show name: Battlefield Friends
# Show rating: None
# Show name: Garfield and Friends
# Show rating: None
# Show name: Unlikely Animal Friends
# Show rating: None
# Show name: Friends from College
# Show rating: 5.1
